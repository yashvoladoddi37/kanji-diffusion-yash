# %% [markdown]
# <a href="https://colab.research.google.com/github/yashvoladoddi37/kanji-diffusion-yash/blob/main/kanji_finetuning_and_inference_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing dependencies, logging into huggingface

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive")
# !git clone https://github.com/huggingface/diffusers
# !pip install git+https://github.com/huggingface/diffusers
os.chdir("diffusers/examples/text_to_image/")
# !pip install -r requirements.txt
# !huggingface-cli login

# %% [markdown]
# Training Script for finetuning Stable Diffusion 1.4, resulting in kanji-diffusion-v1-4

# %%
# !accelerate launch train_text_to_image_lora.py \
  --pretrained_model_name_or_path="CompVis/stable-diffusion-v1-4" \
  --dataset_name="yashvoladoddi37/kanjienglish"
  --caption_column="text" \
  --resolution=512 --random_flip \
  --train_batch_size=1 \
  --num_train_epochs=1 \
  --checkpointing_steps=500 \
  --learning_rate=1e-04 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --seed=42 \
  --output_dir="kanji-diffusion-v1-4" \
  --validation_prompt="A kanji meaning Elon Musk" \
  --push_to_hub

# %% [markdown]
# Training Script for finetuning Stable Diffusion 1.5, resulting in kanji-diffusion-v1-5

# %%
# !accelerate launch train_text_to_image_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --dataset_name="yashvoladoddi37/kanjienglish" \
  --image_column="image" \
  --caption_column="text" \
  --resolution=128 \
  --random_flip \
  --train_batch_size=1 \
  --num_train_epochs=1 \
  --checkpointing_steps=750 \
  --learning_rate=1e-04 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --seed=37 \
  --output_dir="kanji-diffusion-v1-5" \
  --validation_prompt="A kanji meaning Elon Musk" \
  --push_to_hub
# Out:
# Streaming output truncated to the last 5000 lines.
# model.safetensors:  97% 3.33G/3.44G [02:54<00:03, 30.0MB/s]
#
#
#
# model.safetensors:  83% 2.86G/3.44G [02:49<00:39, 14.5MB/s]
#
#
#
# model.safetensors:  83% 2.87G/3.44G [02:49<00:26, 21.6MB/s]
#
#
# model.safetensors:  85% 2.93G/3.44G [02:46<00:20, 24.3MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.98G/3.44G [02:57<02:02, 3.74MB/s]
#
#
#
# model.safetensors:  83% 2.87G/3.44G [02:49<00:25, 22.8MB/s]
#
#
# model.safetensors:  85% 2.94G/3.44G [02:46<00:18, 27.1MB/s]
#
# model.safetensors:  92% 3.17G/3.44G [02:56<00:15, 17.9MB/s]
#
#
#
#
# model.safetensors:  97% 3.33G/3.44G [02:55<00:05, 20.4MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:57<01:10, 6.42MB/s]
#
#
#
# model.safetensors:  84% 2.88G/3.44G [02:49<00:22, 24.8MB/s]
#
#
# model.safetensors:  85% 2.94G/3.44G [02:46<00:18, 27.4MB/s]
#
# model.safetensors:  92% 3.17G/3.44G [02:56<00:11, 23.1MB/s]
#
#
#
#
# model.safetensors:  97% 3.33G/3.44G [02:55<00:04, 22.6MB/s]
#
# model.safetensors:  92% 3.18G/3.44G [02:56<00:11, 22.5MB/s]
#
#
#
# model.safetensors:  84% 2.88G/3.44G [02:49<00:26, 21.3MB/s]
#
#
#
#
# model.safetensors:  97% 3.34G/3.44G [02:55<00:04, 23.7MB/s]
#
# model.safetensors:  92% 3.18G/3.44G [02:56<00:11, 22.4MB/s]
#
#
# model.safetensors:  86% 2.94G/3.44G [02:46<00:26, 18.6MB/s]
#
#
#
#
# model.safetensors:  97% 3.34G/3.44G [02:55<00:03, 26.8MB/s]
#
#
# model.safetensors:  86% 2.95G/3.44G [02:46<00:21, 22.8MB/s]
#
# model.safetensors:  92% 3.18G/3.44G [02:56<00:11, 22.2MB/s]
#
#
#
# model.safetensors:  84% 2.88G/3.44G [02:49<00:38, 14.7MB/s]
#
#
# model.safetensors:  86% 2.95G/3.44G [02:47<00:18, 26.4MB/s]
#
#
#
#
# model.safetensors:  97% 3.34G/3.44G [02:55<00:04, 20.1MB/s]
#
#
#
# model.safetensors:  84% 2.89G/3.44G [02:50<00:27, 20.3MB/s]
#
# model.safetensors:  93% 3.19G/3.44G [02:57<00:13, 18.4MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:57<01:36, 4.68MB/s]
#
#
# model.safetensors:  86% 2.96G/3.44G [02:47<00:15, 30.5MB/s]
#
#
#
#
# model.safetensors:  97% 3.35G/3.44G [02:55<00:03, 25.6MB/s]
#
#
#
# model.safetensors:  84% 2.89G/3.44G [02:50<00:25, 21.5MB/s]
#
# model.safetensors:  93% 3.19G/3.44G [02:57<00:11, 21.3MB/s]
#
#
#
#
# model.safetensors:  97% 3.35G/3.44G [02:56<00:03, 27.3MB/s]
#
# model.safetensors:  93% 3.19G/3.44G [02:57<00:11, 21.8MB/s]
#
#
#
# model.safetensors:  84% 2.89G/3.44G [02:50<00:25, 21.8MB/s]
#
# model.safetensors:  93% 3.19G/3.44G [02:57<00:11, 21.7MB/s]
#
#
# model.safetensors:  86% 2.96G/3.44G [02:47<00:22, 21.4MB/s]
#
#
#
#
# model.safetensors:  98% 3.36G/3.44G [02:56<00:02, 28.8MB/s]
#
#
#
# model.safetensors:  84% 2.89G/3.44G [02:50<00:27, 20.1MB/s]
#
#
#
#
# model.safetensors:  98% 3.36G/3.44G [02:56<00:02, 26.9MB/s]
#
#
# model.safetensors:  86% 2.97G/3.44G [02:47<00:20, 23.6MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:58<01:53, 3.97MB/s]
#
#
#
#
# model.safetensors:  98% 3.37G/3.44G [02:56<00:02, 30.0MB/s]
#
#
# model.safetensors:  86% 2.97G/3.44G [02:47<00:16, 28.8MB/s]
#
#
#
# model.safetensors:  84% 2.90G/3.44G [02:50<00:36, 15.0MB/s]
#
#
#
#
# model.safetensors:  98% 3.37G/3.44G [02:56<00:01, 35.7MB/s]
#
#
# model.safetensors:  86% 2.97G/3.44G [02:47<00:16, 28.3MB/s]
#
#
#
# model.safetensors:  84% 2.90G/3.44G [02:50<00:27, 19.9MB/s]
#
#
#
#
# model.safetensors:  98% 3.38G/3.44G [02:56<00:01, 36.8MB/s]
#
#
#
# model.safetensors:  84% 2.90G/3.44G [02:50<00:22, 23.7MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:58<02:05, 3.59MB/s]
#
#
# model.safetensors:  87% 2.98G/3.44G [02:48<00:19, 23.4MB/s]
#
#
#
# model.safetensors:  84% 2.91G/3.44G [02:51<00:21, 24.6MB/s]
#
#
#
#
# model.safetensors:  98% 3.38G/3.44G [02:56<00:02, 28.1MB/s]
#
#
# model.safetensors:  87% 2.98G/3.44G [02:48<00:16, 28.6MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:58<01:56, 3.86MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [02:58<00:28, 8.65MB/s]
#
#
#
# model.safetensors:  85% 2.91G/3.44G [02:51<00:21, 24.2MB/s]
#
#
# model.safetensors:  87% 2.99G/3.44G [02:48<00:15, 29.5MB/s]
#
#
#
#
# model.safetensors:  98% 3.38G/3.44G [02:57<00:02, 28.4MB/s]
#
#
#
#
# model.safetensors:  98% 3.39G/3.44G [02:57<00:01, 32.2MB/s]
#
#
# model.safetensors:  87% 2.99G/3.44G [02:48<00:16, 28.0MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:59<02:05, 3.58MB/s]
#
#
#
# model.safetensors:  85% 2.91G/3.44G [02:51<00:30, 17.4MB/s]
#
#
# model.safetensors:  87% 2.99G/3.44G [02:48<00:18, 24.4MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:59<02:06, 3.54MB/s]
#
#
#
# model.safetensors:  85% 2.92G/3.44G [02:51<00:22, 23.8MB/s]
#
#
#
#
# model.safetensors:  99% 3.39G/3.44G [02:57<00:02, 23.0MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [02:58<00:37, 6.53MB/s]
#
#
# model.safetensors:  87% 3.00G/3.44G [02:48<00:14, 29.8MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:59<02:00, 3.73MB/s]
#
#
#
# model.safetensors:  85% 2.92G/3.44G [02:51<00:20, 25.7MB/s]
#
#
#
#
# model.safetensors:  99% 3.40G/3.44G [02:57<00:01, 28.8MB/s]
#
#
# model.safetensors:  87% 3.00G/3.44G [02:48<00:14, 31.0MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:59<01:59, 3.75MB/s]
#
#
#
# model.safetensors:  85% 2.92G/3.44G [02:51<00:21, 24.4MB/s]
#
#
#
#
# model.safetensors:  99% 3.40G/3.44G [02:57<00:01, 31.4MB/s]
#
#
# model.safetensors:  87% 3.01G/3.44G [02:48<00:14, 31.1MB/s]
#
#
#
#
# model.safetensors:  99% 3.41G/3.44G [02:57<00:00, 35.4MB/s]
#
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:59<02:18, 3.23MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [02:59<00:45, 5.31MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [02:59<02:07, 3.50MB/s]
#
#
# model.safetensors:  87% 3.01G/3.44G [02:49<00:19, 22.5MB/s]
#
#
#
# model.safetensors:  85% 2.93G/3.44G [02:52<00:31, 16.4MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [02:59<01:34, 4.71MB/s]
#
#
# model.safetensors:  88% 3.02G/3.44G [02:49<00:13, 31.0MB/s]
#
#
#
# model.safetensors:  85% 2.93G/3.44G [02:52<00:22, 22.5MB/s]
#
#
# model.safetensors:  88% 3.02G/3.44G [02:49<00:11, 36.7MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:00<01:38, 4.52MB/s]
#
#
#
# model.safetensors:  85% 2.94G/3.44G [02:52<00:20, 24.5MB/s]
#
#
#
#
# model.safetensors:  99% 3.41G/3.44G [02:58<00:01, 18.7MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [02:59<00:52, 4.57MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:00<01:44, 4.26MB/s]
#
#
#
# model.safetensors:  85% 2.94G/3.44G [02:52<00:19, 25.9MB/s]
#
#
#
#
# model.safetensors:  99% 3.41G/3.44G [02:58<00:01, 20.1MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [02:59<00:49, 4.89MB/s]
#
#
#
# model.safetensors:  86% 2.94G/3.44G [02:52<00:19, 25.9MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:00<01:49, 4.04MB/s]
#
#
#
#
# model.safetensors:  99% 3.42G/3.44G [02:58<00:00, 26.3MB/s]
#
#
# model.safetensors:  88% 3.03G/3.44G [02:49<00:16, 25.8MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [02:59<00:51, 4.63MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:00<01:59, 3.72MB/s]
#
#
# model.safetensors:  88% 3.03G/3.44G [02:49<00:15, 27.0MB/s]
#
#
#
# model.safetensors:  86% 2.95G/3.44G [02:52<00:23, 20.6MB/s]
#
#
# model.safetensors:  88% 3.04G/3.44G [02:49<00:12, 32.1MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [03:00<00:51, 4.64MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:00<01:57, 3.76MB/s]
#
#
#
#
# model.safetensors:  99% 3.42G/3.44G [02:58<00:00, 21.9MB/s]
#
#
#
# model.safetensors:  86% 2.95G/3.44G [02:52<00:21, 23.1MB/s]
#
#
#
#
# model.safetensors: 100% 3.43G/3.44G [02:58<00:00, 27.6MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:00<02:06, 3.51MB/s]
#
#
#
# model.safetensors:  86% 2.95G/3.44G [02:53<00:21, 22.5MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [03:00<00:58, 4.05MB/s]
#
#
#
#
# model.safetensors: 100% 3.44G/3.44G [02:58<00:00, 31.8MB/s]
#
#
# model.safetensors:  88% 3.04G/3.44G [02:50<00:16, 23.9MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:00<02:06, 3.49MB/s]
#
#
#
# model.safetensors:  86% 2.96G/3.44G [02:53<00:20, 23.8MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [03:00<01:02, 3.79MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:01<02:14, 3.27MB/s]
#
#
# model.safetensors:  89% 3.05G/3.44G [02:50<00:13, 28.5MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [03:00<01:02, 3.82MB/s]
#
#
# model.safetensors:  89% 3.05G/3.44G [02:50<00:11, 32.7MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:01<02:09, 3.39MB/s]
#
#
#
# model.safetensors:  86% 2.96G/3.44G [02:53<00:24, 20.0MB/s]
#
# model.safetensors:  93% 3.20G/3.44G [03:00<01:01, 3.86MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:01<01:57, 3.74MB/s]
#
#
#
# model.safetensors:  86% 2.97G/3.44G [02:53<00:17, 26.7MB/s]
#
#
#
#
# model.safetensors: 100% 3.44G/3.44G [02:59<00:00, 19.6MB/s]
#
#
#
# model.safetensors:  86% 2.97G/3.44G [02:53<00:15, 30.3MB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:00<00:57, 4.11MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:01<01:46, 4.12MB/s]
#
#
# model.safetensors:  89% 3.06G/3.44G [02:50<00:15, 25.0MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:01<01:09, 6.31MB/s]
#
#
#
# model.safetensors:  86% 2.97G/3.44G [02:53<00:14, 32.6MB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:00<00:50, 4.70MB/s]
#
#
# model.safetensors:  89% 3.06G/3.44G [02:50<00:12, 30.4MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.00G/3.44G [03:01<01:00, 7.26MB/s]
#
# model.safetensors: 100% 3.44G/3.44G [02:59<00:00, 19.1MB/s]
#
#
#
# model.safetensors:  89% 3.07G/3.44G [02:50<00:10, 35.4MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.01G/3.44G [03:01<00:50, 8.62MB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:01<00:45, 5.12MB/s]
#
#
#
# model.safetensors:  87% 2.98G/3.44G [02:54<00:18, 24.5MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.01G/3.44G [03:01<00:48, 9.00MB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:01<00:44, 5.30MB/s]
#
#
#
# model.safetensors:  87% 2.98G/3.44G [02:54<00:16, 27.8MB/s]
#
#
# model.safetensors:  89% 3.07G/3.44G [02:51<00:13, 27.8MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.01G/3.44G [03:01<00:41, 10.4MB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:01<00:41, 5.62MB/s]
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:54<00:14, 32.4MB/s]
#
#
# model.safetensors:  89% 3.08G/3.44G [02:51<00:11, 32.9MB/s]
#
#
#
#
# optimizer.bin:   0% 0.00/6.59M [00:00<?, ?B/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:01<00:40, 5.72MB/s]
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:54<00:14, 31.8MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.01G/3.44G [03:02<00:48, 8.86MB/s]
#
#
# model.safetensors:  90% 3.08G/3.44G [02:51<00:09, 36.0MB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:01<00:42, 5.45MB/s]
#
#
#
#
#
# model.safetensors:  87% 3.01G/3.44G [03:02<00:38, 11.2MB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:01<00:41, 5.59MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.01G/3.44G [03:02<00:35, 12.0MB/s]
#
#
#
# model.safetensors:  87% 2.99G/3.44G [02:54<00:18, 23.5MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.01G/3.44G [03:02<00:29, 14.4MB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:01<00:35, 6.47MB/s]
#
#
# model.safetensors:  90% 3.09G/3.44G [02:51<00:13, 26.2MB/s]
#
#
#
# model.safetensors:  87% 3.00G/3.44G [02:54<00:15, 28.5MB/s]
#
#
#
#
# optimizer.bin:   0% 16.4k/6.59M [00:00<03:01, 36.2kB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:01<00:28, 7.91MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.02G/3.44G [03:02<00:24, 17.4MB/s]
#
#
# model.safetensors:  90% 3.09G/3.44G [02:51<00:10, 32.8MB/s]
#
#
#
# model.safetensors:  87% 3.00G/3.44G [02:54<00:15, 28.4MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.02G/3.44G [03:02<00:24, 17.6MB/s]
#
#
#
#
# optimizer.bin:   4% 279k/6.59M [00:00<00:10, 606kB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:02<00:30, 7.37MB/s]
#
#
# model.safetensors:  90% 3.10G/3.44G [02:52<00:10, 32.6MB/s]
#
#
#
#
# optimizer.bin:  14% 934k/6.59M [00:00<00:02, 2.00MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.02G/3.44G [03:02<00:24, 16.9MB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:02<00:32, 6.94MB/s]
#
#
# model.safetensors:  90% 3.10G/3.44G [02:52<00:10, 32.6MB/s]
#
#
#
#
# optimizer.bin:  37% 2.41M/6.59M [00:00<00:00, 5.21MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.02G/3.44G [03:02<00:25, 16.4MB/s]
#
# model.safetensors:  93% 3.21G/3.44G [03:02<00:32, 6.86MB/s]
#
#
#
#
# optimizer.bin:  92% 6.05M/6.59M [00:00<00:00, 13.3MB/s]
#
# model.safetensors:  93% 3.22G/3.44G [03:02<00:31, 7.14MB/s]
#
#
#
# model.safetensors:  87% 3.01G/3.44G [02:55<00:23, 18.7MB/s]
#
#
# model.safetensors:  90% 3.11G/3.44G [02:52<00:12, 27.0MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.02G/3.44G [03:03<00:34, 12.1MB/s]
#
# model.safetensors:  93% 3.22G/3.44G [03:02<00:33, 6.79MB/s]
#
#
# model.safetensors:  90% 3.11G/3.44G [02:52<00:09, 33.9MB/s]
#
#
#
# optimizer.bin: 100% 6.59M/6.59M [00:01<00:00, 5.98MB/s]
#
#
#
#
#
#
# model.safetensors:  88% 3.03G/3.44G [03:03<00:22, 18.2MB/s]
#
# model.safetensors:  94% 3.22G/3.44G [03:02<00:28, 7.80MB/s]
#
#
# model.safetensors:  91% 3.12G/3.44G [02:52<00:09, 33.3MB/s]
#
#
#
# model.safetensors:  88% 3.02G/3.44G [02:55<00:17, 23.7MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.03G/3.44G [03:03<00:21, 18.8MB/s]
#
# model.safetensors:  94% 3.22G/3.44G [03:02<00:28, 7.78MB/s]
#
#
#
# model.safetensors:  88% 3.02G/3.44G [02:55<00:16, 24.8MB/s]
#
#
#
#
# pytorch_lora_weights.safetensors:   0% 0.00/3.23M [00:00<?, ?B/s]
#
#
#
#
#
# model.safetensors:  88% 3.03G/3.44G [03:03<00:21, 19.0MB/s]
#
# model.safetensors:  94% 3.22G/3.44G [03:02<00:30, 7.24MB/s]
#
#
# model.safetensors:  91% 3.12G/3.44G [02:52<00:13, 24.0MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.03G/3.44G [03:03<00:21, 19.2MB/s]
#
# model.safetensors:  94% 3.22G/3.44G [03:02<00:27, 8.11MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.04G/3.44G [03:03<00:20, 19.7MB/s]
#
#
# model.safetensors:  91% 3.13G/3.44G [02:52<00:10, 31.1MB/s]
#
# model.safetensors:  94% 3.22G/3.44G [03:03<00:26, 8.24MB/s]
#
#
#
# model.safetensors:  88% 3.02G/3.44G [02:55<00:22, 18.4MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.04G/3.44G [03:03<00:20, 19.5MB/s]
#
#
# model.safetensors:  91% 3.13G/3.44G [02:53<00:08, 35.1MB/s]
#
#
#
#
# pytorch_lora_weights.safetensors:   1% 16.4k/3.23M [00:00<01:14, 42.8kB/s]
#
# model.safetensors:  94% 3.22G/3.44G [03:03<00:27, 7.99MB/s]
#
#
#
# model.safetensors:  88% 3.03G/3.44G [02:56<00:18, 22.7MB/s]
#
#
#
#
# pytorch_lora_weights.safetensors:  49% 1.59M/3.23M [00:00<00:00, 4.14MB/s]
#
# model.safetensors:  94% 3.22G/3.44G [03:03<00:28, 7.75MB/s]
#
#
#
# model.safetensors:  88% 3.03G/3.44G [02:56<00:18, 22.3MB/s]
#
# model.safetensors:  94% 3.22G/3.44G [03:03<00:25, 8.67MB/s]
#
#
#
#
#
# model.safetensors:  88% 3.04G/3.44G [03:04<00:30, 13.0MB/s]
#
#
#
# pytorch_lora_weights.safetensors: 100% 3.23M/3.23M [00:00<00:00, 4.61MB/s]
#
#
#
# model.safetensors:  91% 3.14G/3.44G [02:53<00:13, 22.3MB/s]
#
# model.safetensors:  94% 3.23G/3.44G [03:03<00:15, 13.5MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.05G/3.44G [03:04<00:17, 22.9MB/s]
#
#
# model.safetensors:  91% 3.14G/3.44G [02:53<00:10, 27.4MB/s]
#
#
#
#
# random_states_0.pkl:   0% 0.00/14.4k [00:00<?, ?B/s]
#
#
#
# model.safetensors:  88% 3.04G/3.44G [02:56<00:18, 22.0MB/s]
#
#
# model.safetensors:  92% 3.15G/3.44G [02:53<00:08, 35.2MB/s]
#
#
#
# model.safetensors:  89% 3.05G/3.44G [02:56<00:14, 27.4MB/s]
#
# model.safetensors:  94% 3.23G/3.44G [03:03<00:25, 8.36MB/s]
#
#
#
#
# random_states_0.pkl: 100% 14.4k/14.4k [00:00<00:00, 50.0kB/s]
#
#
#
# model.safetensors:  89% 3.05G/3.44G [02:56<00:13, 29.8MB/s]
#
# model.safetensors:  94% 3.23G/3.44G [03:04<00:26, 7.94MB/s]
#
#
# random_states_0.pkl: 100% 14.4k/14.4k [00:00<00:00, 39.1kB/s]
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [02:56<00:11, 32.5MB/s]
#
#
# model.safetensors:  92% 3.16G/3.44G [02:54<00:09, 29.0MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.05G/3.44G [03:04<00:34, 11.5MB/s]
#
#
#
#
# scheduler.bin:   0% 0.00/1.00k [00:00<?, ?B/s]
#
# model.safetensors:  94% 3.23G/3.44G [03:04<00:31, 6.76MB/s]
#
#
#
# model.safetensors:  89% 3.06G/3.44G [02:57<00:13, 29.3MB/s]
#
#
# model.safetensors:  92% 3.16G/3.44G [02:54<00:08, 34.2MB/s]
#
#
# model.safetensors:  92% 3.17G/3.44G [02:54<00:07, 35.7MB/s]
#
#
#
# model.safetensors:  89% 3.06G/3.44G [02:57<00:12, 30.2MB/s]
#
# model.safetensors:  94% 3.23G/3.44G [03:04<00:34, 6.07MB/s]
#
#
#
#
# scheduler.bin: 100% 1.00k/1.00k [00:00<00:00, 4.28kB/s]
#
#
#
# scheduler.bin: 100% 1.00k/1.00k [00:00<00:00, 3.13kB/s]
#
#
#
#
#
#
# model.safetensors:  89% 3.05G/3.44G [03:05<00:42, 9.06MB/s]
#
#
# model.safetensors:  92% 3.17G/3.44G [02:54<00:09, 29.3MB/s]
#
# model.safetensors:  94% 3.23G/3.44G [03:04<00:42, 4.98MB/s]
#
#
# model.safetensors:  92% 3.18G/3.44G [02:54<00:08, 30.9MB/s]
#
# model.safetensors:  94% 3.23G/3.44G [03:04<00:36, 5.64MB/s]
#
#
# model.safetensors:  92% 3.18G/3.44G [02:54<00:06, 38.5MB/s]
#
#
#
# model.safetensors:  89% 3.07G/3.44G [02:57<00:16, 22.6MB/s]
#
# model.safetensors:  94% 3.23G/3.44G [03:04<00:37, 5.60MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.05G/3.44G [03:05<00:50, 7.70MB/s]
#
#
#
# model.safetensors:  89% 3.08G/3.44G [02:57<00:12, 29.0MB/s]
#
# model.safetensors:  94% 3.23G/3.44G [03:05<00:37, 5.58MB/s]
#
#
#
# model.safetensors:  90% 3.08G/3.44G [02:57<00:10, 34.3MB/s]
#
#
#
#
# model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
#
#
# model.safetensors:  93% 3.19G/3.44G [02:55<00:09, 26.8MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:05<00:51, 7.48MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:05<00:36, 5.61MB/s]
#
#
#
# model.safetensors:  90% 3.09G/3.44G [02:58<00:10, 34.8MB/s]
#
#
# model.safetensors:  93% 3.19G/3.44G [02:55<00:08, 29.2MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:05<00:40, 5.09MB/s]
#
#
# model.safetensors:  93% 3.20G/3.44G [02:55<00:07, 35.0MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:05<00:59, 6.46MB/s]
#
#
#
#
# model.safetensors:   0% 16.4k/3.44G [00:00<17:40:08, 54.1kB/s]
#
#
#
# model.safetensors:  90% 3.09G/3.44G [02:58<00:12, 27.7MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:05<00:42, 4.79MB/s]
#
#
#
# model.safetensors:  90% 3.10G/3.44G [02:58<00:11, 29.8MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:05<00:41, 4.89MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:06<01:02, 6.17MB/s]
#
#
# model.safetensors:  93% 3.20G/3.44G [02:55<00:09, 26.4MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:05<00:39, 5.11MB/s]
#
#
#
# model.safetensors:  90% 3.10G/3.44G [02:58<00:10, 32.1MB/s]
#
#
# model.safetensors:  93% 3.21G/3.44G [02:55<00:07, 32.8MB/s]
#
#
#
#
# model.safetensors:   0% 4.13M/3.44G [00:00<07:15, 7.89MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:06<01:06, 5.74MB/s]
#
#
# model.safetensors:  93% 3.21G/3.44G [02:55<00:07, 32.6MB/s]
#
#
#
#
# model.safetensors:   0% 8.49M/3.44G [00:00<04:10, 13.7MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:05<00:50, 4.00MB/s]
#
#
#
# model.safetensors:  90% 3.11G/3.44G [02:58<00:13, 25.3MB/s]
#
#
# model.safetensors:  93% 3.21G/3.44G [02:55<00:06, 33.5MB/s]
#
#
#
# model.safetensors:  90% 3.11G/3.44G [02:58<00:12, 27.6MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:05<00:53, 3.76MB/s]
#
#
#
#
# model.safetensors:   0% 14.5M/3.44G [00:00<02:41, 21.2MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:06<01:26, 4.40MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:06<00:55, 3.67MB/s]
#
#
#
# model.safetensors:  90% 3.11G/3.44G [02:58<00:12, 26.4MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:06<01:49, 3.48MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:06<01:31, 2.21MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:07<02:10, 2.93MB/s]
#
#
#
# model.safetensors:  91% 3.11G/3.44G [02:59<00:24, 13.4MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:07<02:39, 1.27MB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:10<12:22, 271kB/s]
#
#
#
#
# model.safetensors:   0% 17.1M/3.44G [00:05<29:03, 1.96MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:11<14:25, 440kB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:12<14:18, 235kB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:17<33:20, 190kB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:16<30:55, 109kB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:17<29:17, 217kB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:17<21:58, 152kB/s]
#
#
# model.safetensors:  94% 3.22G/3.44G [03:07<02:57, 1.25MB/s]
#
#
#
# model.safetensors:  91% 3.12G/3.44G [03:09<05:37, 961kB/s]
#
#
#
#
# model.safetensors:   1% 18.8M/3.44G [00:12<1:03:36, 897kB/s]
#
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [03:17<10:41, 591kB/s]
#
# model.safetensors:  94% 3.24G/3.44G [03:17<04:38, 714kB/s]
#
#
# model.safetensors:  94% 3.22G/3.44G [03:07<02:17, 1.59MB/s]
#
#
#
# model.safetensors:  91% 3.12G/3.44G [03:10<04:04, 1.31MB/s]
#
#
#
#
# model.safetensors:   1% 21.4M/3.44G [00:12<45:12, 1.26MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.07G/3.44G [03:17<04:29, 1.40MB/s]
#
# model.safetensors:  94% 3.25G/3.44G [03:17<02:02, 1.60MB/s]
#
#
#
#
# model.safetensors:   1% 25.1M/3.44G [00:12<28:54, 1.97MB/s]
#
# model.safetensors:  94% 3.25G/3.44G [03:17<01:10, 2.76MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.07G/3.44G [03:17<02:21, 2.63MB/s]
#
#
# model.safetensors:  94% 3.23G/3.44G [03:07<01:39, 2.17MB/s]
#
#
#
# model.safetensors:  91% 3.12G/3.44G [03:10<03:07, 1.70MB/s]
#
#
#
#
# model.safetensors:   1% 27.9M/3.44G [00:12<21:09, 2.69MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.07G/3.44G [03:18<01:34, 3.90MB/s]
#
#
# model.safetensors:  94% 3.23G/3.44G [03:07<01:14, 2.87MB/s]
#
#
#
# model.safetensors:  91% 3.12G/3.44G [03:10<02:26, 2.16MB/s]
#
#
#
#
# model.safetensors:   1% 31.5M/3.44G [00:12<14:32, 3.91MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.07G/3.44G [03:18<01:16, 4.83MB/s]
#
#
# model.safetensors:  94% 3.23G/3.44G [03:07<00:56, 3.73MB/s]
#
#
#
# model.safetensors:  91% 3.13G/3.44G [03:10<01:55, 2.74MB/s]
#
# model.safetensors:  94% 3.25G/3.44G [03:17<00:59, 3.23MB/s]
#
#
#
#
# model.safetensors:   1% 34.0M/3.44G [00:12<11:34, 4.91MB/s]
#
#
#
#
#
# model.safetensors:  89% 3.08G/3.44G [03:18<00:43, 8.36MB/s]
#
# model.safetensors:  94% 3.25G/3.44G [03:17<00:40, 4.66MB/s]
#
#
# model.safetensors:  94% 3.23G/3.44G [03:07<00:44, 4.67MB/s]
#
#
#
#
# model.safetensors:   1% 36.4M/3.44G [00:12<09:17, 6.11MB/s]
#
#
#
# model.safetensors:  91% 3.13G/3.44G [03:10<01:19, 3.90MB/s]
#
#
#
#
#
# model.safetensors:  90% 3.08G/3.44G [03:18<00:33, 10.6MB/s]
#
# model.safetensors:  95% 3.25G/3.44G [03:17<00:31, 6.04MB/s]
#
#
# model.safetensors:  94% 3.24G/3.44G [03:07<00:35, 5.71MB/s]
#
#
#
#
# model.safetensors:   1% 39.8M/3.44G [00:12<06:51, 8.27MB/s]
#
#
#
# model.safetensors:  91% 3.13G/3.44G [03:10<01:01, 4.99MB/s]
#
#
#
#
#
# model.safetensors:  90% 3.09G/3.44G [03:18<00:26, 13.5MB/s]
#
# model.safetensors:  95% 3.26G/3.44G [03:18<00:20, 8.87MB/s]
#
#
# model.safetensors:  94% 3.24G/3.44G [03:07<00:29, 6.77MB/s]
#
#
#
#
# model.safetensors:   1% 43.7M/3.44G [00:13<05:09, 11.0MB/s]
#
#
#
# model.safetensors:  91% 3.13G/3.44G [03:11<00:53, 5.73MB/s]
#
# model.safetensors:  95% 3.26G/3.44G [03:18<00:18, 9.89MB/s]
#
#
# model.safetensors:  94% 3.24G/3.44G [03:08<00:25, 7.80MB/s]
#
#
#
#
# model.safetensors:   1% 47.6M/3.44G [00:13<04:09, 13.6MB/s]
#
#
#
#
#
# model.safetensors:  90% 3.09G/3.44G [03:18<00:29, 12.2MB/s]
#
# model.safetensors:  95% 3.26G/3.44G [03:18<00:13, 13.1MB/s]
#
#
# model.safetensors:  94% 3.24G/3.44G [03:08<00:20, 9.85MB/s]
#
#
#
#
#
# model.safetensors:  90% 3.09G/3.44G [03:18<00:21, 16.2MB/s]
#
#
# model.safetensors:  94% 3.25G/3.44G [03:08<00:16, 11.7MB/s]
#
#
#
#
# model.safetensors:   1% 50.0M/3.44G [00:13<04:19, 13.1MB/s]
#
#
#
# model.safetensors:  91% 3.14G/3.44G [03:11<00:52, 5.85MB/s]
#
# model.safetensors:  95% 3.27G/3.44G [03:18<00:14, 12.3MB/s]
#
#
#
#
#
# model.safetensors:  90% 3.10G/3.44G [03:19<00:15, 22.0MB/s]
#
#
#
#
# model.safetensors:   2% 53.6M/3.44G [00:13<03:30, 16.1MB/s]
#
#
#
# model.safetensors:  91% 3.14G/3.44G [03:11<00:33, 9.05MB/s]
#
# model.safetensors:  95% 3.27G/3.44G [03:18<00:12, 14.3MB/s]
#
#
#
#
# model.safetensors:   2% 57.2M/3.44G [00:13<02:53, 19.5MB/s]
#
#
#
#
#
# model.safetensors:  90% 3.10G/3.44G [03:19<00:14, 23.0MB/s]
#
#
# model.safetensors:  94% 3.25G/3.44G [03:08<00:18, 10.6MB/s]
#
#
#
# model.safetensors:  91% 3.14G/3.44G [03:11<00:29, 10.1MB/s]
#
# model.safetensors:  95% 3.27G/3.44G [03:18<00:11, 15.2MB/s]
#
#
#
#
# model.safetensors:   2% 59.9M/3.44G [00:13<02:48, 20.0MB/s]
#
#
# model.safetensors:  94% 3.25G/3.44G [03:08<00:13, 13.6MB/s]
#
#
#
# model.safetensors:  91% 3.14G/3.44G [03:11<00:27, 10.7MB/s]
#
# model.safetensors:  95% 3.27G/3.44G [03:18<00:09, 17.7MB/s]
#
#
#
#
# model.safetensors:   2% 63.3M/3.44G [00:13<02:38, 21.3MB/s]
#
#
# model.safetensors:  95% 3.25G/3.44G [03:08<00:12, 14.5MB/s]
#
#
#
#
#
# model.safetensors:  90% 3.10G/3.44G [03:19<00:19, 17.3MB/s]
#
#
#
# model.safetensors:  91% 3.15G/3.44G [03:11<00:24, 12.2MB/s]
#
# model.safetensors:  95% 3.28G/3.44G [03:19<00:09, 17.9MB/s]
#
#
# model.safetensors:  95% 3.26G/3.44G [03:08<00:11, 15.6MB/s]
#
#
#
#
#
# model.safetensors:  90% 3.11G/3.44G [03:19<00:16, 20.1MB/s]
#
#
#
#
# model.safetensors:   2% 65.8M/3.44G [00:14<03:02, 18.5MB/s]
#
#
#
# model.safetensors:  91% 3.15G/3.44G [03:12<00:21, 13.3MB/s]
#
# model.safetensors:  95% 3.28G/3.44G [03:19<00:07, 20.5MB/s]
#
#
# model.safetensors:  95% 3.26G/3.44G [03:09<00:10, 18.0MB/s]
#
#
#
#
#
# model.safetensors:  90% 3.11G/3.44G [03:19<00:14, 22.5MB/s]
#
#
#
#
# model.safetensors:   2% 68.0M/3.44G [00:14<03:01, 18.6MB/s]
#
#
#
# model.safetensors:  92% 3.15G/3.44G [03:12<00:20, 14.2MB/s]
#
#
# model.safetensors:  95% 3.26G/3.44G [03:09<00:09, 19.8MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.11G/3.44G [03:19<00:14, 22.8MB/s]
#
# model.safetensors:  95% 3.28G/3.44G [03:19<00:09, 16.4MB/s]
#
#
#
#
# model.safetensors:   2% 71.1M/3.44G [00:14<02:48, 20.0MB/s]
#
# model.safetensors:  95% 3.28G/3.44G [03:19<00:09, 17.0MB/s]
#
#
# model.safetensors:  95% 3.26G/3.44G [03:09<00:10, 17.4MB/s]
#
#
#
# model.safetensors:  92% 3.15G/3.44G [03:12<00:25, 11.1MB/s]
#
#
#
#
# model.safetensors:   2% 75.0M/3.44G [00:14<02:32, 22.1MB/s]
#
#
# model.safetensors:  95% 3.27G/3.44G [03:09<00:08, 21.1MB/s]
#
#
#
# model.safetensors:  92% 3.16G/3.44G [03:12<00:18, 15.2MB/s]
#
# model.safetensors:  96% 3.29G/3.44G [03:19<00:07, 19.9MB/s]
#
#
#
#
# model.safetensors:   2% 78.9M/3.44G [00:14<02:19, 24.2MB/s]
#
#
# model.safetensors:  95% 3.27G/3.44G [03:09<00:08, 21.0MB/s]
#
#
#
# model.safetensors:  92% 3.16G/3.44G [03:12<00:18, 15.6MB/s]
#
# model.safetensors:  96% 3.29G/3.44G [03:19<00:07, 20.7MB/s]
#
#
# model.safetensors:  95% 3.27G/3.44G [03:09<00:06, 24.1MB/s]
#
#
#
# model.safetensors:  92% 3.16G/3.44G [03:12<00:15, 18.5MB/s]
#
# model.safetensors:  96% 3.29G/3.44G [03:19<00:06, 23.5MB/s]
#
#
#
#
# model.safetensors:   2% 81.4M/3.44G [00:14<03:22, 16.6MB/s]
#
#
# model.safetensors:  95% 3.28G/3.44G [03:09<00:06, 24.7MB/s]
#
#
#
# model.safetensors:  92% 3.16G/3.44G [03:12<00:15, 18.0MB/s]
#
# model.safetensors:  96% 3.30G/3.44G [03:20<00:07, 20.5MB/s]
#
#
#
#
# model.safetensors:   2% 84.3M/3.44G [00:14<02:58, 18.8MB/s]
#
#
#
# model.safetensors:  92% 3.17G/3.44G [03:13<00:13, 20.2MB/s]
#
# model.safetensors:  96% 3.30G/3.44G [03:20<00:06, 22.9MB/s]
#
#
#
#
# model.safetensors:   3% 87.8M/3.44G [00:15<02:36, 21.4MB/s]
#
#
# model.safetensors:  95% 3.28G/3.44G [03:10<00:08, 19.3MB/s]
#
# model.safetensors:  96% 3.30G/3.44G [03:20<00:04, 27.9MB/s]
#
#
#
#
# model.safetensors:   3% 91.7M/3.44G [00:15<02:14, 25.0MB/s]
#
#
# model.safetensors:  95% 3.28G/3.44G [03:10<00:07, 20.6MB/s]
#
#
#
# model.safetensors:  92% 3.17G/3.44G [03:13<00:17, 15.6MB/s]
#
# model.safetensors:  96% 3.31G/3.44G [03:20<00:05, 26.3MB/s]
#
#
#
#
# model.safetensors:   3% 94.6M/3.44G [00:15<02:11, 25.5MB/s]
#
#
# model.safetensors:  96% 3.29G/3.44G [03:10<00:06, 23.8MB/s]
#
#
#
# model.safetensors:  92% 3.17G/3.44G [03:13<00:14, 18.3MB/s]
#
# model.safetensors:  96% 3.31G/3.44G [03:20<00:04, 28.3MB/s]
#
#
# model.safetensors:  96% 3.29G/3.44G [03:10<00:06, 23.9MB/s]
#
#
#
# model.safetensors:  92% 3.17G/3.44G [03:13<00:14, 19.0MB/s]
#
#
#
#
# model.safetensors:   3% 97.4M/3.44G [00:15<02:43, 20.5MB/s]
#
#
# model.safetensors:  96% 3.29G/3.44G [03:10<00:05, 24.9MB/s]
#
#
#
# model.safetensors:  92% 3.18G/3.44G [03:13<00:12, 21.8MB/s]
#
#
#
#
# model.safetensors:   3% 100M/3.44G [00:15<02:29, 22.3MB/s]
#
#
# model.safetensors:  96% 3.30G/3.44G [03:10<00:06, 24.3MB/s]
#
# model.safetensors:  96% 3.31G/3.44G [03:20<00:06, 19.2MB/s]
#
#
#
# model.safetensors:  92% 3.18G/3.44G [03:13<00:11, 22.2MB/s]
#
#
#
#
# model.safetensors:   3% 104M/3.44G [00:15<02:07, 26.2MB/s]
#
# model.safetensors:  96% 3.32G/3.44G [03:20<00:06, 20.1MB/s]
#
#
#
# model.safetensors:  92% 3.18G/3.44G [03:13<00:11, 22.0MB/s]
#
#
#
#
# model.safetensors:   3% 108M/3.44G [00:15<02:01, 27.3MB/s]
#
# model.safetensors:  96% 3.32G/3.44G [03:20<00:05, 21.5MB/s]
#
#
# model.safetensors:  96% 3.30G/3.44G [03:10<00:08, 17.0MB/s]
#
#
#
#
# model.safetensors:   3% 111M/3.44G [00:15<01:54, 29.0MB/s]
#
# model.safetensors:  97% 3.32G/3.44G [03:21<00:05, 23.2MB/s]
#
#
#
# model.safetensors:  93% 3.18G/3.44G [03:14<00:16, 15.8MB/s]
#
#
# model.safetensors:  96% 3.30G/3.44G [03:11<00:07, 19.5MB/s]
#
# model.safetensors:  97% 3.32G/3.44G [03:21<00:04, 24.7MB/s]
#
#
#
# model.safetensors:  93% 3.19G/3.44G [03:14<00:11, 21.6MB/s]
#
#
# model.safetensors:  96% 3.31G/3.44G [03:11<00:05, 23.6MB/s]
#
# model.safetensors:  97% 3.33G/3.44G [03:21<00:04, 25.0MB/s]
#
#
#
# model.safetensors:  93% 3.19G/3.44G [03:14<00:10, 23.3MB/s]
#
#
#
#
# model.safetensors:   3% 114M/3.44G [00:16<03:07, 17.7MB/s]
#
#
# model.safetensors:  96% 3.31G/3.44G [03:11<00:04, 27.1MB/s]
#
#
#
# model.safetensors:  93% 3.19G/3.44G [03:14<00:09, 24.7MB/s]
#
#
#
#
# model.safetensors:   3% 117M/3.44G [00:16<02:47, 19.9MB/s]
#
#
#
# model.safetensors:  93% 3.20G/3.44G [03:14<00:08, 27.1MB/s]
#
#
#
#
# model.safetensors:   4% 121M/3.44G [00:16<02:22, 23.3MB/s]
#
#
#
#
# model.safetensors:   4% 125M/3.44G [00:16<01:58, 27.9MB/s]
#
#
# model.safetensors:  96% 3.31G/3.44G [03:11<00:07, 18.2MB/s]
#
#
#
# model.safetensors:  93% 3.20G/3.44G [03:14<00:11, 20.4MB/s]
#
# model.safetensors:  97% 3.33G/3.44G [03:21<00:09, 11.8MB/s]
#
#
# model.safetensors:  96% 3.32G/3.44G [03:11<00:06, 19.0MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.12G/3.44G [03:22<01:26, 3.75MB/s]
#
#
#
# model.safetensors:  93% 3.21G/3.44G [03:14<00:09, 24.1MB/s]
#
# model.safetensors:  97% 3.33G/3.44G [03:21<00:07, 14.8MB/s]
#
#
# model.safetensors:  96% 3.32G/3.44G [03:11<00:05, 22.1MB/s]
#
#
#
#
# model.safetensors:   4% 129M/3.44G [00:16<02:47, 19.8MB/s]
#
#
#
# model.safetensors:  93% 3.21G/3.44G [03:14<00:08, 27.3MB/s]
#
# model.safetensors:  97% 3.34G/3.44G [03:22<00:06, 17.4MB/s]
#
#
# model.safetensors:  97% 3.32G/3.44G [03:11<00:04, 25.6MB/s]
#
#
#
#
# model.safetensors:   4% 132M/3.44G [00:17<02:26, 22.5MB/s]
#
#
#
# model.safetensors:  93% 3.21G/3.44G [03:14<00:07, 29.8MB/s]
#
#
# model.safetensors:  97% 3.33G/3.44G [03:12<00:03, 29.8MB/s]
#
# model.safetensors:  97% 3.34G/3.44G [03:22<00:04, 20.3MB/s]
#
#
#
#
# model.safetensors:   4% 136M/3.44G [00:17<02:13, 24.7MB/s]
#
# model.safetensors:  97% 3.34G/3.44G [03:22<00:04, 21.3MB/s]
#
#
#
#
# model.safetensors:   4% 140M/3.44G [00:17<02:06, 26.1MB/s]
#
#
# model.safetensors:  97% 3.33G/3.44G [03:12<00:04, 23.3MB/s]
#
#
#
# model.safetensors:  93% 3.22G/3.44G [03:15<00:10, 20.6MB/s]
#
#
# model.safetensors:  97% 3.33G/3.44G [03:12<00:04, 24.1MB/s]
#
#
#
# model.safetensors:  94% 3.22G/3.44G [03:15<00:09, 24.0MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.12G/3.44G [03:23<01:24, 3.78MB/s]
#
# model.safetensors:  97% 3.35G/3.44G [03:22<00:05, 17.0MB/s]
#
#
# model.safetensors:  97% 3.34G/3.44G [03:12<00:04, 24.2MB/s]
#
#
#
#
# model.safetensors:   4% 144M/3.44G [00:17<02:36, 21.1MB/s]
#
#
#
# model.safetensors:  94% 3.22G/3.44G [03:15<00:08, 26.0MB/s]
#
# model.safetensors:  97% 3.35G/3.44G [03:22<00:04, 19.1MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.12G/3.44G [03:23<01:00, 5.30MB/s]
#
#
# model.safetensors:  97% 3.34G/3.44G [03:12<00:03, 25.5MB/s]
#
#
#
#
# model.safetensors:   4% 147M/3.44G [00:17<02:23, 22.9MB/s]
#
#
#
# model.safetensors:  94% 3.23G/3.44G [03:15<00:07, 27.1MB/s]
#
# model.safetensors:  97% 3.35G/3.44G [03:22<00:04, 22.0MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.13G/3.44G [03:23<00:43, 7.21MB/s]
#
#
#
#
# model.safetensors:   4% 150M/3.44G [00:17<02:24, 22.8MB/s]
#
# model.safetensors:  97% 3.36G/3.44G [03:22<00:03, 22.8MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.13G/3.44G [03:23<00:36, 8.64MB/s]
#
#
# model.safetensors:  97% 3.34G/3.44G [03:12<00:04, 21.8MB/s]
#
#
#
# model.safetensors:  94% 3.23G/3.44G [03:15<00:10, 21.1MB/s]
#
#
#
#
# model.safetensors:   4% 152M/3.44G [00:17<02:32, 21.5MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.13G/3.44G [03:23<00:31, 9.78MB/s]
#
# model.safetensors:  98% 3.36G/3.44G [03:23<00:04, 20.2MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.13G/3.44G [03:23<00:29, 10.4MB/s]
#
#
#
#
# model.safetensors:   5% 156M/3.44G [00:18<02:47, 19.6MB/s]
#
# model.safetensors:  98% 3.36G/3.44G [03:23<00:04, 16.7MB/s]
#
#
#
# model.safetensors:  94% 3.23G/3.44G [03:16<00:14, 14.7MB/s]
#
#
# model.safetensors:  97% 3.35G/3.44G [03:13<00:07, 12.6MB/s]
#
#
#
#
# model.safetensors:   5% 160M/3.44G [00:18<02:35, 21.1MB/s]
#
# model.safetensors:  98% 3.36G/3.44G [03:23<00:04, 16.3MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.14G/3.44G [03:23<00:28, 10.7MB/s]
#
#
#
# model.safetensors:  94% 3.23G/3.44G [03:16<00:12, 16.1MB/s]
#
#
# model.safetensors:  97% 3.35G/3.44G [03:13<00:06, 15.2MB/s]
#
#
#
#
# model.safetensors:   5% 163M/3.44G [00:18<02:21, 23.2MB/s]
#
# model.safetensors:  98% 3.36G/3.44G [03:23<00:04, 16.5MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.14G/3.44G [03:24<00:22, 13.3MB/s]
#
#
#
# model.safetensors:  94% 3.24G/3.44G [03:16<00:10, 18.8MB/s]
#
#
# model.safetensors:  97% 3.35G/3.44G [03:13<00:05, 16.2MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.14G/3.44G [03:24<00:24, 12.1MB/s]
#
#
#
#
# model.safetensors:   5% 166M/3.44G [00:18<03:54, 14.0MB/s]
#
# model.safetensors:  98% 3.37G/3.44G [03:24<00:10, 7.03MB/s]
#
#
#
# model.safetensors:  94% 3.24G/3.44G [03:17<00:22, 9.02MB/s]
#
#
# model.safetensors:  97% 3.35G/3.44G [03:14<00:15, 5.92MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.14G/3.44G [03:25<00:57, 5.24MB/s]
#
#
#
# model.safetensors:  94% 3.24G/3.44G [03:17<00:29, 6.85MB/s]
#
#
#
#
# model.safetensors:   5% 168M/3.44G [00:19<07:44, 7.04MB/s]
#
#
# model.safetensors:  97% 3.35G/3.44G [03:14<00:11, 7.29MB/s]
#
# model.safetensors:  98% 3.37G/3.44G [03:24<00:14, 5.16MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.15G/3.44G [03:25<00:36, 8.04MB/s]
#
#
#
# model.safetensors:  94% 3.25G/3.44G [03:17<00:20, 9.80MB/s]
#
#
#
#
# model.safetensors:   5% 170M/3.44G [00:19<06:02, 9.02MB/s]
#
#
# model.safetensors:  98% 3.36G/3.44G [03:14<00:07, 10.5MB/s]
#
# model.safetensors:  98% 3.37G/3.44G [03:24<00:09, 7.46MB/s]
#
#
#
#
#
# model.safetensors:  91% 3.15G/3.44G [03:25<00:28, 10.4MB/s]
#
#
#
#
# model.safetensors:   5% 173M/3.44G [00:19<04:53, 11.1MB/s]
#
# model.safetensors:  98% 3.37G/3.44G [03:24<00:06, 10.2MB/s]
#
#
#
#
# model.safetensors:   5% 176M/3.44G [00:19<03:56, 13.8MB/s]
#
#
# model.safetensors:  98% 3.36G/3.44G [03:14<00:07, 10.6MB/s]
#
# model.safetensors:  98% 3.37G/3.44G [03:24<00:05, 12.5MB/s]
#
#
#
# model.safetensors:  94% 3.25G/3.44G [03:17<00:19, 9.96MB/s]
#
#
# model.safetensors:  98% 3.36G/3.44G [03:14<00:05, 15.2MB/s]
#
#
#
#
# model.safetensors:   5% 178M/3.44G [00:20<03:52, 14.1MB/s]
#
#
#
# model.safetensors:  95% 3.25G/3.44G [03:17<00:12, 15.4MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.15G/3.44G [03:25<00:27, 10.5MB/s]
#
# model.safetensors:  98% 3.38G/3.44G [03:25<00:05, 12.4MB/s]
#
#
# model.safetensors:  98% 3.37G/3.44G [03:15<00:04, 17.7MB/s]
#
#
#
#
# model.safetensors:   5% 180M/3.44G [00:20<03:32, 15.4MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.15G/3.44G [03:25<00:23, 12.3MB/s]
#
#
#
# model.safetensors:  95% 3.26G/3.44G [03:18<00:11, 16.8MB/s]
#
# model.safetensors:  98% 3.38G/3.44G [03:25<00:04, 14.4MB/s]
#
#
# model.safetensors:  98% 3.37G/3.44G [03:15<00:03, 19.0MB/s]
#
#
#
#
# model.safetensors:   5% 183M/3.44G [00:20<02:59, 18.1MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.16G/3.44G [03:25<00:18, 15.2MB/s]
#
# model.safetensors:  98% 3.38G/3.44G [03:25<00:03, 18.6MB/s]
#
#
#
# model.safetensors:  95% 3.26G/3.44G [03:18<00:10, 16.9MB/s]
#
#
#
#
# model.safetensors:   5% 186M/3.44G [00:20<02:49, 19.2MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.16G/3.44G [03:25<00:15, 18.1MB/s]
#
#
# model.safetensors:  98% 3.37G/3.44G [03:15<00:03, 18.9MB/s]
#
# model.safetensors:  98% 3.39G/3.44G [03:25<00:02, 19.6MB/s]
#
#
#
# model.safetensors:  95% 3.26G/3.44G [03:18<00:10, 17.6MB/s]
#
#
#
#
# model.safetensors:   5% 188M/3.44G [00:20<02:42, 20.0MB/s]
#
#
# model.safetensors:  98% 3.37G/3.44G [03:15<00:03, 19.4MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.16G/3.44G [03:26<00:15, 18.3MB/s]
#
# model.safetensors:  98% 3.39G/3.44G [03:25<00:02, 18.1MB/s]
#
#
#
#
# model.safetensors:   6% 191M/3.44G [00:20<02:38, 20.5MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.17G/3.44G [03:26<00:15, 18.0MB/s]
#
#
#
# model.safetensors:  95% 3.26G/3.44G [03:18<00:11, 15.0MB/s]
#
# model.safetensors:  99% 3.39G/3.44G [03:25<00:02, 17.6MB/s]
#
#
# model.safetensors:  98% 3.38G/3.44G [03:15<00:05, 12.8MB/s]
#
#
#
#
# model.safetensors:   6% 193M/3.44G [00:20<03:46, 14.3MB/s]
#
#
#
# model.safetensors:  95% 3.26G/3.44G [03:18<00:13, 12.7MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.17G/3.44G [03:26<00:18, 14.8MB/s]
#
#
# model.safetensors:  98% 3.38G/3.44G [03:15<00:03, 18.7MB/s]
#
# model.safetensors:  99% 3.39G/3.44G [03:25<00:03, 13.6MB/s]
#
#
#
#
# model.safetensors:   6% 197M/3.44G [00:20<02:47, 19.4MB/s]
#
#
#
# model.safetensors:  95% 3.27G/3.44G [03:18<00:10, 16.8MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.17G/3.44G [03:26<00:13, 19.3MB/s]
#
#
# model.safetensors:  98% 3.39G/3.44G [03:16<00:02, 20.6MB/s]
#
# model.safetensors:  99% 3.40G/3.44G [03:26<00:02, 17.6MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.17G/3.44G [03:26<00:13, 20.0MB/s]
#
#
#
#
# model.safetensors:   6% 200M/3.44G [00:21<02:37, 20.5MB/s]
#
#
#
# model.safetensors:  95% 3.27G/3.44G [03:19<00:10, 16.9MB/s]
#
# model.safetensors:  99% 3.40G/3.44G [03:26<00:02, 17.5MB/s]
#
#
# model.safetensors:  98% 3.39G/3.44G [03:16<00:02, 18.8MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.18G/3.44G [03:26<00:13, 20.0MB/s]
#
#
#
#
# model.safetensors:   6% 203M/3.44G [00:21<02:28, 21.8MB/s]
#
#
#
# model.safetensors:  95% 3.27G/3.44G [03:19<00:09, 17.3MB/s]
#
# model.safetensors:  99% 3.40G/3.44G [03:26<00:02, 18.8MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.18G/3.44G [03:26<00:13, 19.9MB/s]
#
#
#
#
# model.safetensors:   6% 207M/3.44G [00:21<02:23, 22.5MB/s]
#
#
#
# model.safetensors:  95% 3.28G/3.44G [03:19<00:09, 17.3MB/s]
#
#
# model.safetensors:  99% 3.39G/3.44G [03:16<00:02, 17.1MB/s]
#
# model.safetensors:  99% 3.40G/3.44G [03:26<00:02, 18.6MB/s]
#
#
#
#
#
# model.safetensors:  92% 3.18G/3.44G [03:27<00:12, 21.1MB/s]
#
#
#
# model.safetensors:  95% 3.28G/3.44G [03:19<00:10, 15.8MB/s]
#
# model.safetensors:  99% 3.41G/3.44G [03:26<00:01, 18.2MB/s]
#
#
#
#
# model.safetensors:   6% 209M/3.44G [00:21<03:08, 17.2MB/s]
#
#
#
#
#
# model.safetensors:  93% 3.18G/3.44G [03:27<00:14, 17.5MB/s]
#
#
# model.safetensors:  99% 3.39G/3.44G [03:16<00:03, 12.5MB/s]
#
#
#
#
# model.safetensors:   6% 214M/3.44G [00:21<02:29, 21.6MB/s]
#
#
#
# model.safetensors:  95% 3.28G/3.44G [03:19<00:12, 12.8MB/s]
#
#
# model.safetensors:  99% 3.40G/3.44G [03:16<00:02, 17.4MB/s]
#
# model.safetensors:  99% 3.41G/3.44G [03:26<00:02, 14.5MB/s]
#
#
#
#
#
# model.safetensors:  93% 3.19G/3.44G [03:27<00:10, 23.3MB/s]
#
#
#
#
# model.safetensors:   6% 218M/3.44G [00:21<02:08, 25.0MB/s]
#
#
#
# model.safetensors:  95% 3.28G/3.44G [03:19<00:08, 17.6MB/s]
#
#
# model.safetensors:  99% 3.40G/3.44G [03:16<00:02, 18.2MB/s]
#
# model.safetensors:  99% 3.41G/3.44G [03:27<00:01, 18.6MB/s]
#
#
#
#
#
# model.safetensors:  93% 3.19G/3.44G [03:27<00:10, 23.0MB/s]
#
#
#
#
# model.safetensors:   6% 221M/3.44G [00:21<02:11, 24.5MB/s]
#
#
#
# model.safetensors:  95% 3.29G/3.44G [03:19<00:08, 17.3MB/s]
#
#
# model.safetensors:  99% 3.40G/3.44G [03:17<00:02, 18.0MB/s]
#
# model.safetensors:  99% 3.41G/3.44G [03:27<00:01, 18.3MB/s]
#
#
#
#
#
# model.safetensors:  93% 3.20G/3.44G [03:27<00:10, 22.5MB/s]
#
#
#
#
# model.safetensors:   7% 224M/3.44G [00:22<02:18, 23.3MB/s]
#
#
#
# model.safetensors:  96% 3.29G/3.44G [03:20<00:09, 16.7MB/s]
#
#
# model.safetensors:  99% 3.40G/3.44G [03:17<00:02, 17.4MB/s]
#
# model.safetensors:  99% 3.42G/3.44G [03:27<00:01, 19.6MB/s]
#
#
#
#
#
# model.safetensors:  93% 3.20G/3.44G [03:27<00:10, 22.0MB/s]
#
#
#
# model.safetensors:  96% 3.29G/3.44G [03:20<00:09, 16.8MB/s]
#
#
#
#
# model.safetensors:   7% 226M/3.44G [00:22<02:39, 20.1MB/s]
#
#
# model.safetensors:  99% 3.41G/3.44G [03:17<00:02, 17.6MB/s]
#
# model.safetensors:  99% 3.42G/3.44G [03:27<00:01, 19.7MB/s]
#
#
#
# model.safetensors:  96% 3.29G/3.44G [03:20<00:07, 18.9MB/s]
#
#
#
#
# model.safetensors:   7% 228M/3.44G [00:22<02:37, 20.4MB/s]
#
#
# model.safetensors:  99% 3.41G/3.44G [03:17<00:01, 17.6MB/s]
#
# model.safetensors:  99% 3.42G/3.44G [03:27<00:00, 21.5MB/s]
#
#
#
#
#
# model.safetensors:  93% 3.20G/3.44G [03:28<00:14, 16.5MB/s]
#
#
#
# model.safetensors:  96% 3.29G/3.44G [03:20<00:07, 19.1MB/s]
#
#
#
#
# model.safetensors:   7% 232M/3.44G [00:22<02:21, 22.7MB/s]
#
#
#
#
#
# model.safetensors:  93% 3.20G/3.44G [03:28<00:13, 17.7MB/s]
#
#
#
#
# model.safetensors:   7% 234M/3.44G [00:22<02:22, 22.5MB/s]
#
#
#
#
#
# model.safetensors:  93% 3.21G/3.44G [03:28<00:10, 23.1MB/s]
#
# model.safetensors: 100% 3.42G/3.44G [03:27<00:01, 15.5MB/s]
#
#
#
#
# model.safetensors:   7% 239M/3.44G [00:22<01:49, 29.1MB/s]
#
#
#
#
#
# model.safetensors:  93% 3.21G/3.44G [03:28<00:08, 27.7MB/s]
#
#
#
# model.safetensors:  96% 3.30G/3.44G [03:20<00:11, 12.2MB/s]
#
# model.safetensors: 100% 3.43G/3.44G [03:27<00:00, 18.8MB/s]
#
# model.safetensors: 100% 3.43G/3.44G [03:27<00:00, 22.5MB/s]
#
#
#
# model.safetensors:  96% 3.30G/3.44G [03:20<00:08, 15.9MB/s]
#
#
#
#
#
# model.safetensors:  93% 3.22G/3.44G [03:28<00:08, 25.4MB/s]
#
#
#
#
# model.safetensors:   7% 242M/3.44G [00:22<02:26, 21.9MB/s]
#
# model.safetensors: 100% 3.43G/3.44G [03:28<00:00, 24.0MB/s]
#
#
#
#
# model.safetensors:   7% 245M/3.44G [00:23<02:21, 22.6MB/s]
#
#
#
# model.safetensors:  96% 3.30G/3.44G [03:21<00:07, 17.8MB/s]
#
#
# model.safetensors:  99% 3.41G/3.44G [03:18<00:04, 7.01MB/s]
#
#
#
#
# model.safetensors:   7% 249M/3.44G [00:23<01:58, 26.9MB/s]
#
# model.safetensors: 100% 3.44G/3.44G [03:28<00:00, 23.0MB/s]
#
#
#
#
#
# model.safetensors:  94% 3.22G/3.44G [03:28<00:11, 19.0MB/s]
#
#
#
# model.safetensors:  96% 3.31G/3.44G [03:21<00:07, 18.7MB/s]
#
#
#
#
#
# model.safetensors:  94% 3.22G/3.44G [03:28<00:11, 19.7MB/s]
#
#
#
#
# model.safetensors:   7% 253M/3.44G [00:23<02:07, 25.1MB/s]
#
# model.safetensors: 100% 3.44G/3.44G [03:28<00:00, 19.6MB/s]
#
#
# model.safetensors:  99% 3.41G/3.44G [03:18<00:03, 8.19MB/s]
#
#
#
#
#
# model.safetensors:  94% 3.22G/3.44G [03:29<00:10, 20.8MB/s]
#
#
#
# model.safetensors:  96% 3.31G/3.44G [03:21<00:06, 19.9MB/s]
#
#
# model.safetensors:  99% 3.41G/3.44G [03:18<00:03, 9.17MB/s]
#
#
#
#
#
# model.safetensors:  94% 3.23G/3.44G [03:29<00:10, 21.1MB/s]
#
#
# model.safetensors: 100% 3.44G/3.44G [03:28<00:00, 16.5MB/s]
#
#
#
#
#
#
# model.safetensors:  94% 3.23G/3.44G [03:29<00:09, 22.8MB/s]
#
#
#
# model.safetensors:  96% 3.31G/3.44G [03:21<00:07, 16.4MB/s]
#
#
#
#
# model.safetensors:   7% 256M/3.44G [00:23<03:07, 17.0MB/s]
#
#
# model.safetensors:  99% 3.42G/3.44G [03:18<00:01, 15.6MB/s]
#
#
#
#
# model.safetensors:   8% 261M/3.44G [00:23<02:25, 21.9MB/s]
#
#
#
# model.safetensors:  96% 3.32G/3.44G [03:21<00:06, 18.8MB/s]
#
#
#
#
#
# model.safetensors:  94% 3.23G/3.44G [03:29<00:10, 19.9MB/s]
#
#
#
#
# model.safetensors:   8% 264M/3.44G [00:23<02:10, 24.3MB/s]
#
#
#
#
#
# model.safetensors:  94% 3.24G/3.44G [03:29<00:08, 23.8MB/s]
#
#
#
# model.safetensors:  96% 3.32G/3.44G [03:21<00:06, 20.1MB/s]
#
# optimizer.bin:   0% 0.00/6.58M [00:00<?, ?B/s]
#
#
#
#
#
# model.safetensors:  94% 3.24G/3.44G [03:29<00:08, 24.0MB/s]
#
#
# model.safetensors:  99% 3.42G/3.44G [03:19<00:01, 13.7MB/s]
#
#
#
#
# model.safetensors:   8% 267M/3.44G [00:24<02:23, 22.2MB/s]
#
#
#
# model.safetensors:  97% 3.32G/3.44G [03:22<00:06, 19.1MB/s]
#
# optimizer.bin:  34% 2.24M/6.58M [00:00<00:00, 21.8MB/s]
#
#
#
#
#
# model.safetensors:  94% 3.24G/3.44G [03:29<00:07, 28.2MB/s]
#
#
# model.safetensors: 100% 3.43G/3.44G [03:19<00:00, 17.3MB/s]
#
#
#
#
# model.safetensors:   8% 270M/3.44G [00:24<02:10, 24.2MB/s]
#
#
#
# model.safetensors:  97% 3.33G/3.44G [03:22<00:05, 22.7MB/s]
#
# optimizer.bin:  74% 4.87M/6.58M [00:00<00:00, 24.1MB/s]
#
#
#
#
#
# model.safetensors:  94% 3.25G/3.44G [03:29<00:07, 24.8MB/s]
#
#
# model.safetensors: 100% 3.43G/3.44G [03:19<00:00, 17.7MB/s]
#
#
#
# model.safetensors:  97% 3.33G/3.44G [03:22<00:06, 16.3MB/s]
#
#
# model.safetensors: 100% 3.43G/3.44G [03:19<00:00, 18.7MB/s]
#
#
#
#
# model.safetensors:   8% 273M/3.44G [00:24<03:02, 17.4MB/s]
#
#
#
#
#
# model.safetensors:  94% 3.25G/3.44G [03:30<00:10, 18.6MB/s]
#
#
# model.safetensors: 100% 3.44G/3.44G [03:19<00:00, 21.9MB/s]
#
#
#
#
# model.safetensors:   8% 278M/3.44G [00:24<02:23, 22.1MB/s]
#
#
#
# optimizer.bin: 100% 6.58M/6.58M [00:00<00:00, 10.2MB/s]
#
#
#
#
#
#
# model.safetensors:  94% 3.25G/3.44G [03:30<00:08, 21.3MB/s]
#
#
#
# model.safetensors:  97% 3.34G/3.44G [03:22<00:05, 20.7MB/s]
#
#
#
#
# model.safetensors:   8% 281M/3.44G [00:24<02:17, 22.9MB/s]
#
#
#
#
#
# model.safetensors:  95% 3.25G/3.44G [03:30<00:08, 22.0MB/s]
#
#
#
#
# model.safetensors:   8% 285M/3.44G [00:24<02:08, 24.5MB/s]
#
#
#
# model.safetensors:  97% 3.34G/3.44G [03:22<00:04, 21.1MB/s]
#
#
#
#
#
# model.safetensors:  95% 3.26G/3.44G [03:30<00:07, 23.8MB/s]
#
# pytorch_lora_weights.safetensors:   0% 0.00/3.23M [00:00<?, ?B/s]
#
#
#
# model.safetensors:  97% 3.34G/3.44G [03:22<00:04, 24.1MB/s]
#
#
#
#
#
# model.safetensors:  95% 3.26G/3.44G [03:30<00:07, 25.5MB/s]
#
#
# model.safetensors: 100% 3.44G/3.44G [03:20<00:00, 11.4MB/s]
#
#
#
#
# model.safetensors:   8% 288M/3.44G [00:25<02:57, 17.8MB/s]
#
#
#
# pytorch_lora_weights.safetensors: 100% 3.23M/3.23M [00:00<00:00, 9.18MB/s]
#
#
#
#
#
# model.safetensors:   9% 295M/3.44G [00:25<01:54, 27.6MB/s]
#
#
#
#
#
# model.safetensors: 100% 3.44G/3.44G [03:20<00:00, 17.2MB/s]
#
#
#
#
#
# model.safetensors:   9% 299M/3.44G [00:25<01:47, 29.3MB/s]
#
#
#
#
#
# model.safetensors:  95% 3.27G/3.44G [03:30<00:07, 23.5MB/s]
#
#
#
# model.safetensors:  97% 3.35G/3.44G [03:23<00:04, 21.8MB/s]
#
#
#
#
#
# model.safetensors:  95% 3.27G/3.44G [03:31<00:06, 25.2MB/s]
#
# random_states_0.pkl:   0% 0.00/14.1k [00:00<?, ?B/s]
#
#
#
#
# model.safetensors:   9% 304M/3.44G [00:25<01:47, 29.3MB/s]
#
#
#
# model.safetensors:  97% 3.35G/3.44G [03:23<00:03, 22.6MB/s]
#
#
#
#
#
# model.safetensors:  95% 3.28G/3.44G [03:31<00:06, 26.8MB/s]
#
#
#
# random_states_0.pkl: 100% 14.1k/14.1k [00:00<00:00, 93.1kB/s]
#
#
#
#
#
# model.safetensors:   9% 307M/3.44G [00:25<02:00, 26.0MB/s]
#
#
#
#
#
# model.safetensors:  95% 3.28G/3.44G [03:31<00:05, 29.1MB/s]
#
# scheduler.bin:   0% 0.00/1.00k [00:00<?, ?B/s]
#
#
#
#
# model.safetensors:   9% 310M/3.44G [00:25<01:57, 26.7MB/s]
#
#
#
# model.safetensors:  98% 3.36G/3.44G [03:23<00:03, 20.5MB/s]
#
#
#
#
#
# model.safetensors:  95% 3.28G/3.44G [03:31<00:06, 23.1MB/s]
#
#
#
#
# scheduler.bin: 100% 1.00k/1.00k [00:00<00:00, 7.12kB/s]
#
#
# events.out.tfevents.1723532299.47a02fa9b6bf.5736.1:   0% 0.00/2.24k [00:00<?, ?B/s]
#
#
#
# model.safetensors:  98% 3.37G/3.44G [03:23<00:02, 28.2MB/s]
#
#
#
#
# model.safetensors:   9% 319M/3.44G [00:25<01:32, 33.8MB/s]
#
#
#
#
#
# model.safetensors:  95% 3.29G/3.44G [03:31<00:06, 23.6MB/s]
#
#
#
# events.out.tfevents.1723532299.47a02fa9b6bf.5736.1: 100% 2.24k/2.24k [00:00<00:00, 15.0kB/s]
#
#
#
#
#
#
# model.safetensors:  96% 3.29G/3.44G [03:31<00:05, 26.6MB/s]
#
#
#
# model.safetensors:  98% 3.37G/3.44G [03:24<00:02, 26.2MB/s]
#
#
#
#
# model.safetensors:   9% 323M/3.44G [00:26<01:56, 26.9MB/s]
#
# events.out.tfevents.1723536930.47a02fa9b6bf.24529.1:   0% 0.00/2.24k [00:00<?, ?B/s]
#
#
#
#
#
# model.safetensors:  96% 3.30G/3.44G [03:31<00:04, 33.2MB/s]
#
#
#
# model.safetensors:  98% 3.37G/3.44G [03:24<00:02, 26.5MB/s]
#
#
#
#
# model.safetensors:   9% 326M/3.44G [00:26<01:51, 28.0MB/s]
#
#
# events.out.tfevents.1723536930.47a02fa9b6bf.24529.1: 100% 2.24k/2.24k [00:00<00:00, 15.4kB/s]
#
#
#
#
#
# events.out.tfevents.1723537035.47a02fa9b6bf.24985.1: 100% 2.24k/2.24k [00:00<00:00, 15.3kB/s]
#
#
#
#
# model.safetensors:  98% 3.38G/3.44G [03:24<00:02, 21.7MB/s]
#
#
#
#
# model.safetensors:  10% 334M/3.44G [00:26<01:32, 33.7MB/s]
#
#
#
#
#
# model.safetensors:  96% 3.30G/3.44G [03:32<00:06, 22.8MB/s]
#
# events.out.tfevents.1723539732.4d05fb544bde.2832.1:   0% 0.00/2.24k [00:00<?, ?B/s]
#
#
# events.out.tfevents.1723532299.47a02fa9b6bf.5736.0:   0% 0.00/2.39k [00:00<?, ?B/s]
#
#
#
#
#
# model.safetensors:  96% 3.30G/3.44G [03:32<00:05, 24.3MB/s]
#
#
#
# model.safetensors:  98% 3.38G/3.44G [03:24<00:02, 24.2MB/s]
#
#
#
#
# model.safetensors:  10% 338M/3.44G [00:26<02:05, 24.8MB/s]
#
#
#
#
#
# events.out.tfevents.1723539732.4d05fb544bde.2832.1: 100% 2.24k/2.24k [00:00<00:00, 13.7kB/s]
# events.out.tfevents.1723532299.47a02fa9b6bf.5736.0: 100% 2.39k/2.39k [00:00<00:00, 21.0kB/s]
#
#
#
#
# model.safetensors:  98% 3.39G/3.44G [03:24<00:01, 27.1MB/s]
#
#
#
#
#
# model.safetensors:  96% 3.31G/3.44G [03:32<00:04, 28.6MB/s]
#
#
#
# model.safetensors:  99% 3.39G/3.44G [03:24<00:01, 27.7MB/s]
#
#
#
#
# model.safetensors:  10% 342M/3.44G [00:26<02:00, 25.6MB/s]
#
# events.out.tfevents.1723536930.47a02fa9b6bf.24529.0:   0% 0.00/88.0 [00:00<?, ?B/s]
#
#
# events.out.tfevents.1723539732.4d05fb544bde.2832.0:   0% 0.00/3.06M [00:00<?, ?B/s]
#
#
#
#
# events.out.tfevents.1723536930.47a02fa9b6bf.24529.0: 100% 88.0/88.0 [00:00<00:00, 549B/s]
#
#
#
#
# model.safetensors:  99% 3.39G/3.44G [03:25<00:02, 19.6MB/s]
#
#
#
#
#
# model.safetensors:  96% 3.31G/3.44G [03:32<00:07, 16.7MB/s]
#
#
#
# model.safetensors:  99% 3.40G/3.44G [03:25<00:01, 25.8MB/s]
#
# pytorch_lora_weights.safetensors:   0% 0.00/3.23M [00:00<?, ?B/s]
#
#
#
#
# model.safetensors:  10% 352M/3.44G [00:27<02:02, 25.1MB/s]
#
#
#
#
#
# model.safetensors:  96% 3.32G/3.44G [03:33<00:06, 20.7MB/s]
#
#
#
# model.safetensors:  99% 3.40G/3.44G [03:25<00:01, 29.0MB/s]
#
#
#
#
# model.safetensors:  10% 357M/3.44G [00:27<01:48, 28.5MB/s]
#
#
#
#
#
# model.safetensors:  96% 3.32G/3.44G [03:33<00:05, 21.8MB/s]
#
#
#
#
# model.safetensors:  10% 361M/3.44G [00:27<01:44, 29.4MB/s]
#
#
#
# events.out.tfevents.1723539732.4d05fb544bde.2832.0: 100% 3.06M/3.06M [00:00<00:00, 5.20MB/s]
#
#
#
#
#
#
# model.safetensors:  97% 3.32G/3.44G [03:33<00:05, 23.5MB/s]
#
#
#
#
# model.safetensors:  11% 364M/3.44G [00:27<01:43, 29.8MB/s]
#
#
#
#
#
# model.safetensors:  97% 3.33G/3.44G [03:33<00:04, 25.1MB/s]
#
#
#
# model.safetensors:  99% 3.41G/3.44G [03:25<00:01, 22.9MB/s]
#
#
#
#
#
# model.safetensors:  97% 3.33G/3.44G [03:33<00:04, 23.4MB/s]
#
#
#
# model.safetensors:  99% 3.41G/3.44G [03:25<00:01, 24.4MB/s]
#
#
#
#
# model.safetensors:  11% 368M/3.44G [00:27<02:06, 24.3MB/s]
#
#
#
#
#
# model.safetensors:  97% 3.33G/3.44G [03:33<00:04, 27.1MB/s]
#
#
#
# model.safetensors:  99% 3.42G/3.44G [03:25<00:00, 27.1MB/s]
#
#
#
#
# pytorch_lora_weights.safetensors: 100% 3.23M/3.23M [00:00<00:00, 4.56MB/s]
#
#
#
#
#
#
# model.safetensors:  97% 3.34G/3.44G [03:33<00:03, 26.7MB/s]
#
#
#
# ...
#
#
#
#
# model.safetensors:  28% 950M/3.44G [00:52<01:08, 36.2MB/s]
#
#
#
#
# model.safetensors:  28% 960M/3.44G [00:53<01:13, 33.6MB/s]
#
#
#
#
# model.safetensors:  28% 974M/3.44G [00:53<00:53, 46.5MB/s]
#
#
#
#
# model.safetensors:  29% 982M/3.44G [00:53<00:56, 43.3MB/s]
#
#
#
#
# model.safetensors:  29% 991M/3.44G [00:53<00:48, 50.5MB/s]
#
#
#
#
# model.safetensors:  29% 998M/3.44G [00:53<00:50, 47.9MB/s]
#
#
#
#
# model.safetensors:  29% 1.01G/3.44G [00:53<00:53, 45.3MB/s]
#
#
#
#
# model.safetensors:  30% 1.02G/3.44G [00:54<00:39, 61.8MB/s]
#
#
#
#
# model.safetensors:  30% 1.03G/3.44G [00:54<01:07, 35.9MB/s]
#
#
#
#
# model.safetensors:  30% 1.04G/3.44G [00:54<01:07, 35.8MB/s]
#
#
#
#
# model.safetensors:  31% 1.05G/3.44G [00:54<00:48, 49.0MB/s]
#
#
#
#
# model.safetensors:  31% 1.06G/3.44G [00:55<00:49, 48.5MB/s]
#
#
#
#
# model.safetensors:  31% 1.07G/3.44G [00:55<00:50, 46.5MB/s]
#
#
#
#
# model.safetensors:  32% 1.09G/3.44G [00:55<00:38, 61.4MB/s]
#
#
#
#
# model.safetensors:  32% 1.09G/3.44G [00:55<00:42, 55.4MB/s]
#
#
#
#
# model.safetensors:  32% 1.10G/3.44G [00:56<00:54, 43.2MB/s]
#
#
#
#
# model.safetensors:  32% 1.12G/3.44G [00:56<00:40, 58.0MB/s]
#
#
#
#
# model.safetensors:  33% 1.13G/3.44G [00:56<00:49, 47.2MB/s]
#
#
#
#
# model.safetensors:  33% 1.14G/3.44G [00:56<01:06, 34.5MB/s]
#
#
#
#
# model.safetensors:  33% 1.15G/3.44G [00:56<00:48, 47.5MB/s]
#
#
#
#
# model.safetensors:  34% 1.16G/3.44G [00:57<00:51, 43.9MB/s]
#
#
#
#
# model.safetensors:  34% 1.17G/3.44G [00:57<00:57, 39.3MB/s]
#
#
#
#
# model.safetensors:  34% 1.18G/3.44G [00:57<00:42, 53.0MB/s]
#
#
#
#
# model.safetensors:  35% 1.19G/3.44G [00:57<00:49, 45.2MB/s]
#
#
#
#
# model.safetensors:  35% 1.20G/3.44G [00:58<00:52, 42.6MB/s]
#
#
#
#
# model.safetensors:  35% 1.21G/3.44G [00:58<00:42, 52.1MB/s]
#
#
#
#
# model.safetensors:  35% 1.22G/3.44G [00:58<00:45, 48.7MB/s]
#
#
#
#
# model.safetensors:  36% 1.23G/3.44G [00:58<00:35, 62.6MB/s]
#
#
#
#
# model.safetensors:  36% 1.24G/3.44G [00:58<00:43, 50.5MB/s]
#
#
#
#
# model.safetensors:  36% 1.25G/3.44G [00:59<00:50, 43.5MB/s]
#
#
#
#
# model.safetensors:  37% 1.26G/3.44G [00:59<00:37, 57.8MB/s]
#
#
#
#
# model.safetensors:  37% 1.27G/3.44G [00:59<00:39, 55.1MB/s]
#
#
#
#
# model.safetensors:  37% 1.28G/3.44G [00:59<00:54, 39.4MB/s]
#
#
#
#
# model.safetensors:  38% 1.29G/3.44G [00:59<00:39, 54.2MB/s]
#
#
#
#
# model.safetensors:  38% 1.30G/3.44G [01:00<00:45, 46.5MB/s]
#
#
#
#
# model.safetensors:  38% 1.31G/3.44G [01:00<00:47, 45.2MB/s]
#
#
#
#
# model.safetensors:  39% 1.33G/3.44G [01:00<00:34, 60.7MB/s]
#
#
#
#
# model.safetensors:  39% 1.33G/3.44G [01:00<00:47, 44.7MB/s]
#
#
#
#
# model.safetensors:  39% 1.34G/3.44G [01:01<00:52, 40.3MB/s]
#
#
#
#
# model.safetensors:  39% 1.36G/3.44G [01:01<00:38, 53.7MB/s]
#
#
#
#
# model.safetensors:  40% 1.37G/3.44G [01:01<00:44, 46.9MB/s]
#
#
#
#
# model.safetensors:  40% 1.38G/3.44G [01:01<00:47, 43.8MB/s]
#
#
#
#
# model.safetensors:  40% 1.39G/3.44G [01:01<00:39, 52.4MB/s]
#
#
#
#
# model.safetensors:  40% 1.39G/3.44G [01:02<00:40, 50.2MB/s]
#
#
#
#
# model.safetensors:  41% 1.41G/3.44G [01:02<00:30, 66.0MB/s]
#
#
#
#
# model.safetensors:  41% 1.41G/3.44G [01:02<00:43, 46.9MB/s]
#
#
#
#
# model.safetensors:  41% 1.42G/3.44G [01:02<00:47, 42.5MB/s]
#
#
#
#
# model.safetensors:  42% 1.43G/3.44G [01:02<00:38, 52.2MB/s]
#
#
#
#
# model.safetensors:  42% 1.44G/3.44G [01:03<00:47, 41.8MB/s]
#
#
#
#
# model.safetensors:  42% 1.46G/3.44G [01:03<00:34, 57.7MB/s]
#
#
#
#
# model.safetensors:  43% 1.46G/3.44G [01:03<00:42, 46.3MB/s]
#
#
#
#
# model.safetensors:  43% 1.47G/3.44G [01:03<00:49, 40.1MB/s]
#
#
#
#
# model.safetensors:  43% 1.49G/3.44G [01:03<00:35, 54.9MB/s]
#
#
#
#
# model.safetensors:  43% 1.49G/3.44G [01:04<00:37, 52.5MB/s]
#
#
#
#
# model.safetensors:  44% 1.50G/3.44G [01:04<01:08, 28.5MB/s]
#
#
#
#
# model.safetensors:  44% 1.52G/3.44G [01:04<00:47, 40.1MB/s]
#
#
#
#
# model.safetensors:  44% 1.53G/3.44G [01:05<00:50, 38.3MB/s]
#
#
#
#
# model.safetensors:  45% 1.54G/3.44G [01:05<00:52, 36.5MB/s]
#
#
#
#
# model.safetensors:  45% 1.55G/3.44G [01:05<00:38, 49.6MB/s]
#
#
#
#
# model.safetensors:  45% 1.56G/3.44G [01:05<00:41, 45.9MB/s]
#
#
#
#
# model.safetensors:  46% 1.57G/3.44G [01:06<00:50, 36.8MB/s]
#
#
#
#
# model.safetensors:  46% 1.58G/3.44G [01:06<00:37, 49.4MB/s]
#
#
#
#
# model.safetensors:  46% 1.59G/3.44G [01:06<00:42, 43.8MB/s]
#
#
#
#
# model.safetensors:  46% 1.60G/3.44G [01:06<00:38, 47.8MB/s]
#
#
#
#
# model.safetensors:  47% 1.61G/3.44G [01:06<00:29, 61.8MB/s]
#
#
#
#
# model.safetensors:  47% 1.62G/3.44G [01:06<00:32, 56.7MB/s]
#
#
#
#
# model.safetensors:  47% 1.63G/3.44G [01:07<00:39, 45.4MB/s]
#
#
#
#
# model.safetensors:  48% 1.65G/3.44G [01:07<00:30, 59.0MB/s]
#
#
#
#
# model.safetensors:  48% 1.65G/3.44G [01:08<00:59, 30.1MB/s]
#
#
#
#
# model.safetensors:  48% 1.66G/3.44G [01:08<00:50, 34.9MB/s]
#
#
#
#
# model.safetensors:  49% 1.68G/3.44G [01:08<00:37, 47.5MB/s]
#
#
#
#
# model.safetensors:  49% 1.69G/3.44G [01:08<00:39, 44.2MB/s]
#
#
#
#
# model.safetensors:  49% 1.70G/3.44G [01:08<00:40, 43.1MB/s]
#
#
#
#
# model.safetensors:  50% 1.71G/3.44G [01:08<00:30, 57.1MB/s]
#
#
#
#
# model.safetensors:  50% 1.72G/3.44G [01:09<00:34, 50.3MB/s]
#
#
#
#
# model.safetensors:  50% 1.73G/3.44G [01:09<00:38, 44.9MB/s]
#
#
#
#
# model.safetensors:  51% 1.74G/3.44G [01:09<00:28, 59.0MB/s]
#
#
#
#
# model.safetensors:  51% 1.75G/3.44G [01:09<00:36, 46.2MB/s]
#
#
#
#
# model.safetensors:  51% 1.76G/3.44G [01:10<00:39, 42.1MB/s]
#
#
#
#
# model.safetensors:  52% 1.77G/3.44G [01:10<00:30, 55.4MB/s]
#
#
#
#
# model.safetensors:  52% 1.78G/3.44G [01:10<00:53, 31.2MB/s]
#
#
#
#
# model.safetensors:  52% 1.79G/3.44G [01:11<00:50, 32.7MB/s]
#
#
#
#
# model.safetensors:  52% 1.81G/3.44G [01:11<00:36, 45.3MB/s]
#
#
#
#
# model.safetensors:  53% 1.81G/3.44G [01:11<00:39, 41.5MB/s]
#
#
#
#
# model.safetensors:  53% 1.82G/3.44G [01:12<00:50, 32.2MB/s]
#
#
#
#
# model.safetensors:  53% 1.83G/3.44G [01:12<01:00, 26.6MB/s]
#
#
#
#
# model.safetensors:  53% 1.84G/3.44G [01:12<00:44, 35.8MB/s]
#
#
#
#
# model.safetensors:  54% 1.85G/3.44G [01:12<00:55, 28.7MB/s]
#
#
#
#
# model.safetensors:  54% 1.86G/3.44G [01:13<00:58, 27.3MB/s]
#
#
#
#
# model.safetensors:  54% 1.87G/3.44G [01:13<00:38, 40.6MB/s]
#
#
#
#
# model.safetensors:  55% 1.88G/3.44G [01:13<00:39, 39.7MB/s]
#
#
#
#
# model.safetensors:  55% 1.89G/3.44G [01:13<00:44, 34.6MB/s]
#
#
#
#
# model.safetensors:  55% 1.90G/3.44G [01:14<00:32, 47.2MB/s]
#
#
#
#
# model.safetensors:  55% 1.91G/3.44G [01:14<00:40, 37.7MB/s]
#
#
#
#
# model.safetensors:  56% 1.92G/3.44G [01:14<00:43, 35.0MB/s]
#
#
#
#
# model.safetensors:  56% 1.93G/3.44G [01:14<00:32, 47.0MB/s]
#
#
#
#
# model.safetensors:  56% 1.94G/3.44G [01:15<00:43, 34.6MB/s]
#
#
#
#
# model.safetensors:  57% 1.95G/3.44G [01:15<00:51, 29.1MB/s]
#
#
#
#
# model.safetensors:  57% 1.97G/3.44G [01:15<00:36, 40.8MB/s]
#
#
#
#
# model.safetensors:  57% 1.97G/3.44G [01:16<00:40, 36.2MB/s]
#
#
#
#
# model.safetensors:  58% 1.98G/3.44G [01:16<00:38, 37.8MB/s]
#
#
#
#
# model.safetensors:  58% 2.00G/3.44G [01:16<00:27, 52.0MB/s]
#
#
#
#
# model.safetensors:  58% 2.01G/3.44G [01:16<00:37, 38.2MB/s]
#
#
#
#
# model.safetensors:  59% 2.02G/3.44G [01:17<00:34, 41.9MB/s]
#
#
#
#
# model.safetensors:  59% 2.03G/3.44G [01:17<00:25, 56.1MB/s]
#
#
#
#
# model.safetensors:  59% 2.04G/3.44G [01:17<00:34, 40.4MB/s]
#
#
#
#
# model.safetensors:  60% 2.05G/3.44G [01:17<00:31, 43.8MB/s]
#
#
#
#
# model.safetensors:  60% 2.06G/3.44G [01:17<00:23, 57.9MB/s]
#
#
#
#
# model.safetensors:  60% 2.07G/3.44G [01:18<00:28, 48.6MB/s]
#
#
#
#
# model.safetensors:  60% 2.08G/3.44G [01:18<00:32, 42.0MB/s]
#
#
#
#
# model.safetensors:  61% 2.09G/3.44G [01:18<00:24, 55.4MB/s]
#
#
#
#
# model.safetensors:  61% 2.10G/3.44G [01:18<00:25, 51.6MB/s]
#
#
#
#
# model.safetensors:  61% 2.11G/3.44G [01:19<00:40, 32.6MB/s]
#
#
#
#
# model.safetensors:  62% 2.13G/3.44G [01:19<00:29, 44.2MB/s]
#
#
#
#
# model.safetensors:  62% 2.13G/3.44G [01:19<00:37, 35.3MB/s]
#
#
#
#
# model.safetensors:  62% 2.14G/3.44G [01:20<00:33, 38.2MB/s]
#
#
#
#
# model.safetensors:  63% 2.16G/3.44G [01:20<00:24, 51.5MB/s]
#
#
#
#
# model.safetensors:  63% 2.17G/3.44G [01:20<00:26, 47.7MB/s]
#
#
#
#
# model.safetensors:  63% 2.18G/3.44G [01:20<00:27, 46.5MB/s]
#
#
#
#
# model.safetensors:  64% 2.19G/3.44G [01:20<00:20, 60.6MB/s]
#
#
#
#
# model.safetensors:  64% 2.20G/3.44G [01:20<00:23, 53.4MB/s]
#
#
#
#
# model.safetensors:  64% 2.21G/3.44G [01:21<00:28, 42.6MB/s]
#
#
#
#
# model.safetensors:  65% 2.22G/3.44G [01:21<00:21, 56.0MB/s]
#
#
#
#
# model.safetensors:  65% 2.23G/3.44G [01:21<00:22, 53.2MB/s]
#
#
#
#
# model.safetensors:  65% 2.24G/3.44G [01:21<00:25, 46.7MB/s]
#
#
#
#
# model.safetensors:  65% 2.25G/3.44G [01:21<00:19, 60.3MB/s]
#
#
#
#
# model.safetensors:  66% 2.26G/3.44G [01:22<00:24, 47.2MB/s]
#
#
#
#
# model.safetensors:  66% 2.27G/3.44G [01:22<00:24, 47.5MB/s]
#
#
#
#
# model.safetensors:  66% 2.29G/3.44G [01:22<00:18, 62.2MB/s]
#
#
#
#
# model.safetensors:  67% 2.29G/3.44G [01:22<00:19, 58.2MB/s]
#
#
#
#
# model.safetensors:  67% 2.30G/3.44G [01:22<00:19, 57.4MB/s]
#
#
#
#
# model.safetensors:  67% 2.32G/3.44G [01:22<00:15, 72.4MB/s]
#
#
#
#
# model.safetensors:  68% 2.33G/3.44G [01:23<00:19, 58.6MB/s]
#
#
#
#
# model.safetensors:  68% 2.34G/3.44G [01:23<00:27, 40.1MB/s]
#
#
#
#
# model.safetensors:  68% 2.34G/3.44G [01:24<00:51, 21.4MB/s]
#
#
#
#
# model.safetensors:  68% 2.35G/3.44G [01:24<00:42, 25.8MB/s]
#
#
#
#
# model.safetensors:  69% 2.37G/3.44G [01:24<00:28, 38.0MB/s]
#
#
#
#
# model.safetensors:  69% 2.37G/3.44G [01:25<00:30, 34.7MB/s]
#
#
#
#
# model.safetensors:  69% 2.38G/3.44G [01:25<00:28, 36.6MB/s]
#
#
#
#
# model.safetensors:  70% 2.40G/3.44G [01:25<00:21, 49.5MB/s]
#
#
#
#
# model.safetensors:  70% 2.40G/3.44G [01:25<00:22, 45.6MB/s]
#
#
#
#
# model.safetensors:  70% 2.42G/3.44G [01:25<00:22, 45.6MB/s]
#
#
#
#
# model.safetensors:  71% 2.43G/3.44G [01:25<00:16, 60.0MB/s]
#
#
#
#
# model.safetensors:  71% 2.44G/3.44G [01:26<00:18, 52.9MB/s]
#
#
#
#
# model.safetensors:  71% 2.45G/3.44G [01:26<00:21, 46.5MB/s]
#
#
#
#
# model.safetensors:  72% 2.46G/3.44G [01:26<00:16, 60.6MB/s]
#
#
#
#
# model.safetensors:  72% 2.47G/3.44G [01:26<00:20, 47.0MB/s]
#
#
#
#
# model.safetensors:  72% 2.48G/3.44G [01:27<00:20, 46.9MB/s]
#
#
#
#
# model.safetensors:  72% 2.49G/3.44G [01:27<00:15, 60.0MB/s]
#
#
#
#
# model.safetensors:  73% 2.50G/3.44G [01:27<00:17, 53.4MB/s]
#
#
#
#
# model.safetensors:  73% 2.51G/3.44G [01:27<00:19, 47.1MB/s]
#
#
#
#
# model.safetensors:  73% 2.53G/3.44G [01:27<00:15, 60.6MB/s]
#
#
#
#
# model.safetensors:  74% 2.53G/3.44G [01:28<00:18, 50.0MB/s]
#
#
#
#
# model.safetensors:  74% 2.54G/3.44G [01:28<00:20, 44.5MB/s]
#
#
#
#
# model.safetensors:  74% 2.56G/3.44G [01:28<00:14, 59.3MB/s]
#
#
#
#
# model.safetensors:  75% 2.57G/3.44G [01:28<00:18, 48.4MB/s]
#
#
#
#
# model.safetensors:  75% 2.58G/3.44G [01:28<00:17, 49.4MB/s]
#
#
#
#
# model.safetensors:  75% 2.59G/3.44G [01:29<00:13, 65.2MB/s]
#
#
#
#
# model.safetensors:  76% 2.60G/3.44G [01:29<00:15, 52.9MB/s]
#
#
#
#
# model.safetensors:  76% 2.61G/3.44G [01:29<00:17, 48.1MB/s]
#
#
#
#
# model.safetensors:  76% 2.61G/3.44G [01:30<00:41, 20.1MB/s]
#
#
#
#
# model.safetensors:  76% 2.62G/3.44G [01:30<00:33, 24.1MB/s]
#
#
#
#
# model.safetensors:  77% 2.64G/3.44G [01:30<00:23, 34.6MB/s]
#
#
#
#
# model.safetensors:  77% 2.64G/3.44G [01:31<00:23, 34.1MB/s]
#
#
#
#
# model.safetensors:  77% 2.66G/3.44G [01:31<00:17, 44.5MB/s]
#
#
#
#
# model.safetensors:  77% 2.66G/3.44G [01:31<00:20, 38.4MB/s]
#
#
#
#
# model.safetensors:  78% 2.67G/3.44G [01:31<00:21, 36.6MB/s]
#
#
#
#
# model.safetensors:  78% 2.69G/3.44G [01:31<00:14, 50.5MB/s]
#
#
#
#
# model.safetensors:  78% 2.69G/3.44G [01:32<00:20, 36.7MB/s]
#
#
#
#
# model.safetensors:  79% 2.70G/3.44G [01:32<00:19, 37.5MB/s]
#
#
#
#
# model.safetensors:  79% 2.72G/3.44G [01:32<00:14, 51.1MB/s]
#
#
#
#
# model.safetensors:  79% 2.73G/3.44G [01:32<00:15, 45.8MB/s]
#
#
#
#
# model.safetensors:  80% 2.74G/3.44G [01:33<00:17, 39.3MB/s]
#
#
#
#
# model.safetensors:  80% 2.75G/3.44G [01:33<00:13, 52.6MB/s]
#
#
#
#
# model.safetensors:  80% 2.76G/3.44G [01:33<00:14, 47.5MB/s]
#
#
#
#
# model.safetensors:  80% 2.77G/3.44G [01:33<00:17, 38.7MB/s]
#
#
#
#
# model.safetensors:  81% 2.78G/3.44G [01:33<00:12, 52.0MB/s]
#
#
#
#
# model.safetensors:  81% 2.79G/3.44G [01:34<00:14, 46.4MB/s]
#
#
#
#
# model.safetensors:  81% 2.80G/3.44G [01:34<00:13, 46.2MB/s]
#
#
#
#
# model.safetensors:  82% 2.81G/3.44G [01:34<00:10, 61.7MB/s]
#
#
#
#
# model.safetensors:  82% 2.82G/3.44G [01:34<00:11, 51.8MB/s]
#
#
#
#
# model.safetensors:  82% 2.83G/3.44G [01:34<00:11, 51.8MB/s]
#
#
#
#
# model.safetensors:  83% 2.85G/3.44G [01:35<00:08, 66.2MB/s]
#
#
#
#
# model.safetensors:  83% 2.85G/3.44G [01:35<00:16, 35.1MB/s]
#
#
#
#
# model.safetensors:  83% 2.86G/3.44G [01:35<00:15, 36.8MB/s]
#
#
#
#
# model.safetensors:  84% 2.88G/3.44G [01:35<00:11, 50.2MB/s]
#
#
#
#
# model.safetensors:  84% 2.89G/3.44G [01:36<00:11, 49.1MB/s]
#
#
#
#
# model.safetensors:  84% 2.90G/3.44G [01:36<00:11, 47.6MB/s]
#
#
#
#
# model.safetensors:  85% 2.91G/3.44G [01:36<00:08, 61.7MB/s]
#
#
#
#
# model.safetensors:  85% 2.92G/3.44G [01:36<00:08, 58.9MB/s]
#
#
#
#
# model.safetensors:  85% 2.93G/3.44G [01:36<00:10, 50.4MB/s]
#
#
#
#
# model.safetensors:  85% 2.94G/3.44G [01:37<00:07, 66.3MB/s]
#
#
#
#
# model.safetensors:  86% 2.95G/3.44G [01:37<00:11, 41.8MB/s]
#
#
#
#
# model.safetensors:  86% 2.96G/3.44G [01:37<00:12, 38.0MB/s]
#
#
#
#
# model.safetensors:  86% 2.97G/3.44G [01:37<00:09, 51.0MB/s]
#
#
#
#
# model.safetensors:  87% 2.98G/3.44G [01:38<00:10, 45.6MB/s]
#
#
#
#
# model.safetensors:  87% 2.99G/3.44G [01:38<00:11, 39.9MB/s]
#
#
#
#
# model.safetensors:  87% 3.01G/3.44G [01:38<00:08, 53.0MB/s]
#
#
#
#
# model.safetensors:  88% 3.01G/3.44G [01:38<00:08, 51.7MB/s]
#
#
#
#
# model.safetensors:  88% 3.02G/3.44G [01:39<00:10, 39.2MB/s]
#
#
#
#
# model.safetensors:  88% 3.04G/3.44G [01:39<00:07, 52.9MB/s]
#
#
#
#
# model.safetensors:  89% 3.05G/3.44G [01:39<00:08, 47.6MB/s]
#
#
#
#
# model.safetensors:  89% 3.05G/3.44G [01:39<00:07, 50.1MB/s]
#
#
#
#
# model.safetensors:  89% 3.06G/3.44G [01:39<00:08, 44.3MB/s]
#
#
#
#
# model.safetensors:  89% 3.07G/3.44G [01:39<00:09, 39.3MB/s]
#
#
#
#
# model.safetensors:  89% 3.07G/3.44G [01:40<00:11, 31.5MB/s]
#
#
#
#
# model.safetensors:  89% 3.07G/3.44G [01:40<00:12, 29.7MB/s]
#
#
#
#
# model.safetensors:  89% 3.08G/3.44G [01:40<00:12, 30.2MB/s]
#
#
#
#
# model.safetensors:  90% 3.09G/3.44G [01:40<00:09, 37.9MB/s]
#
#
#
#
# model.safetensors:  90% 3.09G/3.44G [01:40<00:11, 29.8MB/s]
#
#
#
#
# model.safetensors:  90% 3.10G/3.44G [01:41<00:08, 39.0MB/s]
#
#
#
#
# model.safetensors:  90% 3.10G/3.44G [01:41<00:10, 32.2MB/s]
#
#
#
#
# model.safetensors:  90% 3.11G/3.44G [01:41<00:10, 33.2MB/s]
#
#
#
#
# model.safetensors:  90% 3.11G/3.44G [01:41<00:12, 26.8MB/s]
#
#
#
#
# model.safetensors:  91% 3.12G/3.44G [01:41<00:10, 30.5MB/s]
#
#
#
#
# model.safetensors:  91% 3.12G/3.44G [01:41<00:11, 27.8MB/s]
#
#
#
#
# model.safetensors:  91% 3.13G/3.44G [01:42<00:08, 38.7MB/s]
#
#
#
#
# model.safetensors:  91% 3.13G/3.44G [01:42<00:20, 15.3MB/s]
#
#
#
#
# model.safetensors:  91% 3.14G/3.44G [01:43<00:33, 9.05MB/s]
#
#
#
#
# model.safetensors:  92% 3.15G/3.44G [01:43<00:16, 18.1MB/s]
#
#
#
#
# model.safetensors:  92% 3.16G/3.44G [01:44<00:14, 19.5MB/s]
#
#
#
#
# model.safetensors:  92% 3.17G/3.44G [01:44<00:09, 30.0MB/s]
#
#
#
#
# model.safetensors:  92% 3.17G/3.44G [01:45<00:15, 17.4MB/s]
#
#
#
#
# model.safetensors:  93% 3.18G/3.44G [01:45<00:12, 20.0MB/s]
#
#
#
#
# model.safetensors:  93% 3.20G/3.44G [01:45<00:08, 30.5MB/s]
#
#
#
#
# model.safetensors:  93% 3.20G/3.44G [01:45<00:07, 30.1MB/s]
#
#
#
#
# model.safetensors:  93% 3.22G/3.44G [01:46<00:06, 33.4MB/s]
#
#
#
#
# model.safetensors:  94% 3.23G/3.44G [01:46<00:04, 46.1MB/s]
#
#
#
#
# model.safetensors:  94% 3.24G/3.44G [01:46<00:05, 40.2MB/s]
#
#
#
#
# model.safetensors:  94% 3.25G/3.44G [01:46<00:04, 41.8MB/s]
#
#
#
#
# model.safetensors:  95% 3.26G/3.44G [01:46<00:03, 57.0MB/s]
#
#
#
#
# model.safetensors:  95% 3.27G/3.44G [01:46<00:03, 52.3MB/s]
#
#
#
#
# model.safetensors:  95% 3.28G/3.44G [01:47<00:03, 46.3MB/s]
#
#
#
#
# model.safetensors:  96% 3.29G/3.44G [01:47<00:02, 61.2MB/s]
#
#
#
#
# model.safetensors:  96% 3.30G/3.44G [01:47<00:02, 54.1MB/s]
#
#
#
#
# model.safetensors:  96% 3.31G/3.44G [01:47<00:02, 52.1MB/s]
#
#
#
#
# model.safetensors:  97% 3.33G/3.44G [01:47<00:01, 66.9MB/s]
#
#
#
#
# model.safetensors:  97% 3.33G/3.44G [01:48<00:01, 54.5MB/s]
#
#
#
#
# model.safetensors:  97% 3.34G/3.44G [01:48<00:01, 53.4MB/s]
#
#
#
#
# model.safetensors:  98% 3.36G/3.44G [01:48<00:01, 67.9MB/s]
#
#
#
#
# model.safetensors:  98% 3.37G/3.44G [01:48<00:01, 47.9MB/s]
#
#
#
#
# model.safetensors:  98% 3.38G/3.44G [01:48<00:01, 46.8MB/s]
#
#
#
#
# model.safetensors:  98% 3.39G/3.44G [01:49<00:00, 60.8MB/s]
#
#
#
#
# model.safetensors:  99% 3.40G/3.44G [01:49<00:00, 53.2MB/s]
#
#
#
#
# model.safetensors:  99% 3.41G/3.44G [01:49<00:00, 46.2MB/s]
#
#
#
#
# model.safetensors:  99% 3.42G/3.44G [01:49<00:00, 60.4MB/s]
#
#
#
#
# model.safetensors: 100% 3.43G/3.44G [01:49<00:00, 60.0MB/s]
#
#
#
#
# model.safetensors: 100% 3.44G/3.44G [01:50<00:00, 31.2MB/s]
#
# Upload 38 LFS files: 100% 38/38 [04:56<00:00,  7.79s/it]
# Steps: 100% 5082/5082 [31:49<00:00,  2.66it/s, lr=0.0001, step_loss=0.0769]

# %% [markdown]
# Building a LoRa pipeline for finetuned model (version 1.4)

# %%
from diffusers import StableDiffusionPipeline
import torch

model_path = "yashvoladoddi37/kanji-diffusion-v1-4"
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", torch_dtype=torch.float16, use_safetensors = True).to("cuda")
pipe.unet.load_attn_procs(model_path)
pipe.to("cuda")

prompt = "a Kanji meaning YouTube"
image = pipe(prompt).images[0]
image.save("youtube-kanji-v1-4.png")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# Building a LoRa pipeline for finetuned model (version 1.5)

# %%
from diffusers import StableDiffusionPipeline
import torch

model_path = "yashvoladoddi37/kanji-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16, use_safetensors = True).to("cuda")
pipe.unet.load_attn_procs(model_path)
pipe.to("cuda")

prompt = "a Kanji meaning YouTube"
image = pipe(prompt).images[0]
image.save("youtube-kanji-v1-4.png")
